# %%
import os
import time
from collections import Counter
import logging
import argparse

# helper modules
from ml_utils import pickle_classifier, load_classifier, ExtractFeature, \
                     precision_recall_matrix, get_classifier_results
from nlp_helper import CleanTextTransformer, tokenize_text
from query_events import execute_query

import pandas as pd
import numpy as np

from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer


from scipy.sparse import coo_matrix, hstack

# %%
logname = 'log/event_classifier_log'
logging.basicConfig(filename=logname,
                    filemode='a',
                    format='%(asctime)s -  %(name)s - %(levelname)s - %(message)s',
                    datefmt='%H:%M:%S',
                    level=logging.DEBUG)
logger = logging.getLogger(__name__)


parser = argparse.ArgumentParser(description='This is the event classifier program.')
parser.add_argument('--level', help='Level of classification, \
        usage: --level primary', choices=["primary", "secondary", "tertiary"], required=True)
parser.add_argument('--retrain', help='Retrain classifier. usage: --retrain F',
                    choices=['T', 'F'], required=True)
parser.add_argument('--load_clf', help='Load existing classifier. \
        usage: --load_clf classifiers/SVM_06202017121413.pkl', nargs='+', required=False)
parser.add_argument('--event_ids', help='Enter events to classify. If blank \
        then query will fetch all training data. usage: --event_ids 998746 \
        33384956 114992', nargs='+', required=False)
#filepath = os.path.dirname(__file__)
CLASSIFIER_DIR = os.path.join('/Users/iman/code/event_classifier/model/pickles/classifiers/')

# Getting event text for classifier
QUERY_ALL = """

SELECT event_id
, p_class
, s_class
, t_class
, event_name as event_name
, event_type as event_type
, event_host as event_host
, event_subject as event_subject
, text_paper as event_text
, created
FROM (
    SELECT ce.event_id
    , CASE WHEN ce.p_class = 'skip' THEN 'other' ELSE ce.p_class END
    , CASE WHEN ce.s_class = 'skip' THEN 'other' ELSE ce.s_class END
    , CASE WHEN ce.t_class = 'skip' THEN 'other' ELSE ce.t_class END
    , e.name as event_name
    , e.type as event_type
    , e.host as event_host
    , e.subject as event_subject
    , listagg(TRIM(lower(cat.text))) as text_paper
    , ce.created_at as created
    FROM event_training_selections ce
    JOIN events e ON e.id = ce.event_id
    JOIN cards c ON c.event_id = ce.event_id
    JOIN card_sides cs ON cs.card_id = c.id
        AND cs.side_type_id = 0
    LEFT JOIN card_assets cat ON cat.card_side_id = cs.id
        AND cat.asset_type_id = 9
    WHERE ce.is_confirmed
    GROUP BY 1, 2, 3, 4, 5, 6, 7, 8, 10
    )
WHERE len(trim(event_name || ' ' || event_host || ' ' || event_subject ||
        ' ' || text_paper))
ORDER BY random()

"""

QUERY_EVENTS = """

SELECT event_id
, event_name as event_name
, event_type as event_type
, event_host as event_host
, event_subject as event_subject
, text_paper as event_text
, created
FROM (
    SELECT e.id as event_id
    , e.name as event_name
    , e.type as event_type
    , e.host as event_host
    , e.subject as event_subject
    , listagg(TRIM(lower(cat.text))) as text_paper
    , e.created_at as created
    FROM events e
    JOIN cards c ON c.event_id = e.id
    JOIN card_sides cs ON cs.card_id = c.id
        AND cs.side_type_id = 0
    LEFT JOIN card_assets cat ON cat.card_side_id = cs.id
        AND cat.asset_type_id = 9
    WHERE e.id LIKE {0}
    GROUP BY 1, 2, 3, 4, 5, 7
    )
WHERE len(trim(event_name || ' ' || event_host || ' ' || event_subject ||
        ' ' || text_paper))
ORDER BY random()

"""

# %%
def most_common(lst):
    """
    Using Counter find most common element in list
    Possible results:
        mc = [(val1,3)]
        mc = [(val1,2),(val2,1)]
        mc = [(val1,1),(val2,1),(val3,1)]
        ...
    No majority exists only when there is a tie, otherwise the first value of
    the list is the most common (because Counter sorts automatically in
    descending order by value)
    """

    # check if top two most common predictions are the same
    mc = Counter(lst).most_common(2)

    if len(mc) > 1 and mc[0][1] == mc[1][1]:
        return "no_majority"

    return mc[0][0]


def get_ensemble_prediction(results, classes):
    """
    if majority of classifiers choose same category, that's the winner.
    if majority does not exist, then select class with highest probability
    """

    print("Getting ensemble predictions...")
    num_clfs = len(results)

    # combine all classifier predictions and probabilities
    all_preds = np.array([v[0] for k, v in results.items()]).T
    all_probs = np.sum(np.array([v[1] for k, v in results.items()]), axis=0)
    all_probs_normalize = all_probs/num_clfs

    # the function most_common returns majority class or "no_majority"
    majority = np.array(list(map(most_common, all_preds)))
    no_majority_index = np.where(majority == 'no_majority')

    # for those where a majority doesn't exist, sum the probabilities for each
    # class
    no_majority_sum = all_probs_normalize[no_majority_index]

    # ensure no new probabilities were added that shouldn't be
    assert np.allclose(np.sum(no_majority_sum), len(no_majority_index[0])), (
           "probability sum is greater than expected for no_majority")

    # replace the "no_majority" samples with the class that resulted in the
    # largest probability
    majority[no_majority_index] = classes[np.argmax(no_majority_sum, axis=1)]

    return majority, np.max(all_probs_normalize, axis=1)

# %%
def load_classifier_list(clf):
    """
    Load a classifier
    Classifier is stored as list object
    Returns list of classifiers and their names
    """

    print("Loading classifier list...")
    # clean up input: remove "classifier/" and ".pkl"
    clf_id = clf[clf.find('/')+1:-4]

    clf_list, clf_names = [], []
    # this is a list of classifiers
    loaded_clf = load_classifier(CLASSIFIER_DIR + clf_id)
    for classifier in loaded_clf:
        clf_list.append(classifier)

        # get name via class structure
        clf_class = str(classifier.named_steps['clf'].__class__)

        # some basic cleaning of class name
        clf_name_indx = clf_class.find('.')
        clf_name = clf_class[clf_name_indx+1:-2]
        clf_names.append(clf_name)

    return clf_list, clf_names

# %%
def check_event_types(df):
    
    acceptable_event_types = np.array([
        'BasicAnnouncement', 'DatedAnnouncement', 'GreetingCard', 'LinkAway', 'RsvpEvent'])
    
    for i in df.event_type.values:
        assert (i in acceptable_event_types) == True, "Found event type that doesn't exist"

# %%
def check_primary_classes(y):
    
    acceptable_primary_classes = np.array([
        'birthday_celebration', 'greetings', 'organizations', 'other',
       'personal', 'wedding_related'])
    
    for i in y.primary.values:
        assert (i in acceptable_primary_classes) == True, "Found event type that doesn't exist"

# %%
def check_null(df):
    """
    Ensure no NULL values
    """
    
    assert np.sum(pd.isnull(df).values) == 0, "Some NULL values exist"

# %%
def clean_df(df):
    """
    Perform any necessary cleaning
    
    1) Remove other class types
    2) ensure no NULL values
    3) ensure event_types are corrects
    4) ensure primary classes are correct
    
    """
    
    df[~(df.s_class == 'other')].copy()
    
    
    check_null(df)
    check_event_types(df)
    check_primary_classes(y)
    
    return df

# %%
def get_X_and_y(df):
    """
    Input: dataframe based on query
    Output: X and y (type dataframe)
    """

    df = clean_df(df)
    
    X = pd.DataFrame([df.event_subject, df.event_text, df.event_type]).T
    X.columns = ['subject', 'text', 'event_type']

    y = pd.DataFrame([df.p_class, df.s_class, df.t_class]).T
    y.columns = ['primary', 'secondary', 'tertiary']

    assert X.shape[0] == y.shape[0], 'X and y must be of same dimension'

    
    return X, y

# %%
def save_secondary_features(feature_pipeline, level, id_num):
    """
    Save training features
    Need to create an id_num to know which classifier to load
    Loaded classifier must be the same as the feature id number
    """

    logger.info("Saving secondaryfitted feature pipeline id {}...".format(id_num))
    pickle_classifier(feature_pipeline, FEATURE_DIR + level + "_" + str(id_num))

    return id_num

# %%
def save_classifier(clf, level, id_num):
    """
    Save trained classifier
    """

    logger.info("Saving trained classifier id {}...".format(id_num))
    pickle_classifier(clf, CLASSIFIER_DIR + level + str(id_num))

# %%
# parameters for gridsearch
# using SVM currently
CLASSIFIER_PIPELINE = dict({
    'SVM': {
        'classifier': Pipeline([
            ("clf", SVC(probability=True)),
        ]),
        'params': {
            'clf__C': [1],
            'clf__kernel': ['linear']
        }
     },
})

# %%
def check_dimensions(X, subject_matrix, text_matrix, event_type_matrix, predicted_primary_matrix):
    
    assert (X.shape[1] == subject_matrix.shape[1] + text_matrix.shape[1] + \
            event_type_matrix.shape[1] + predicted_primary_matrix.shape[1]), \
    ("Number of x_train features doesn't match sum of component features")
    
    assert (X.shape[0] == subject_matrix.shape[0]),\
    ("Number of x_train samples doesn't match subject_matrix samples")

    assert (X.shape[0] == text_matrix.shape[0]), \
    ("Number of x_train samples doesn't match body text samples")
    
    assert (X.shape[0] == event_type_matrix.shape[0]),\
    ("Number of x_train samples doesn't match event_type_matrix samples")

    assert (X.shape[0] == predicted_primary_matrix.shape[0]),\
    ("Number of x_train samples doesn't match event_type_matrix samples")

# %%
def grid_search(X, y, gridsearch_pipeline):
    """
    Perform a Grid Search over the space of classifiers and their associated
    parameter space
    Inputs: X and y training sets
    Output: A list of the best classifiers from each classifier category
    """

    logger.info("starting Gridsearch...")

    best_classifiers = []
    names = []

    for v in gridsearch_pipeline.items():
        gs = GridSearchCV(v[1]['classifier'], v[1]['params'], verbose=2, cv=3, n_jobs=4)
        gs = gs.fit(X, y)
        names.append(v[0])
        logger.info("{} finished".format(v[0]))
        logger.info("Best scoring classifier: {}".format(gs.best_score_))
        best_classifiers.append(gs.best_estimator_)

    return best_classifiers, names

# %%
FEATURE_PIPELINE = dict({
    'subject_pipe':Pipeline([
                    ('cleanText', CleanTextTransformer()),
                    ('vectorizer', CountVectorizer(tokenizer=tokenize_text,ngram_range=(1, 1))),
                    ('tfidf', TfidfTransformer())
                    ]),
    'text_pipe': Pipeline([
                    ('cleanText', CleanTextTransformer()),
                    ('vectorizer', CountVectorizer(tokenizer=tokenize_text,ngram_range=(1, 1))),
                    ('tfidf', TfidfTransformer())
                    ]),
    'event_type_pipe': Pipeline([('vectorizer', CountVectorizer())]),
    'predicted_primary': Pipeline([('vectorizer', CountVectorizer())])
})

# %%
def get_secondary_training_features(X, y, pipes):
    """
    Combines training features
    Using fit_transform on the pipeline object for each feature
    Performs sparse matrix concatenation
    """
    
    print("Beginning pipeline fit_transform to training data...")
    
    subject_matrix = pipes['subject_pipe'].fit_transform(X.subject, y)
    text_matrix = pipes['text_pipe'].fit_transform(X.text, y)
    event_type_matrix = pipes['event_type_pipe'].fit_transform(X.event_type, y)
    predicted_primary_matrix = pipes['predicted_primary'].fit_transform(X.pred_primary_class, y)
    
    X = hstack([subject_matrix, text_matrix, event_type_matrix, predicted_primary_matrix])
    
    print("Completed fit_transform")
    
    check_dimensions(X, subject_matrix, text_matrix, event_type_matrix, predicted_primary_matrix)
    print("Training set dimension:", X.shape)
    
    return X, pipes

# %%
def get_secondary_testing_features(X, pipes):
    """
    Combines training features
    Key difference between this and training_features
    is that pipeline is transforming x_test not fit_transforming
    """
    
    print("Beginning transform of test set...")
    subject_matrix = pipes['subject_pipe'].transform(X.subject)
    text_matrix = pipes['text_pipe'].transform(X.text)
    event_type_matrix = pipes['event_type_pipe'].transform(X.event_type)
    predicted_primary_matrix = pipes['predicted_primary'].transform(X.pred_primary_class)
    
    X = hstack([subject_matrix, text_matrix, event_type_matrix, predicted_primary_matrix])
    
    print("Completed transform of test set.")
    
    check_dimensions(X, subject_matrix, text_matrix, event_type_matrix, predicted_primary_matrix)
    print("Testing set dimension:", X.shape)
    
    return X

# %%
def _check_prediction_dimensions(y_test, y_pred, y_score):
    """
    Ensure that prediction dimensions are correct
    """

    assert y_pred.shape[0] == y_test.shape[0], (
        "Ensure class prediction vector is same length as test set")
    assert y_score.shape[0] == y_test.shape[0], (
        "Ensure score prediction vector is same length as test set")

# %%
# load dataset
df = pd.read_pickle('pickles/primary_output/dataset_674.pkl')

# %%
df
# Out:
#                                           subject  \
# 16106                            Thank you, Noemi
# 18656                      Devin's First Birthday
# 385                 Alyse Bowser's Birthday Party
# 2448                          Nada's 8th Birthday
# 10250                         To someone special
# 15498                 CSC Leasing Christmas Party
# 16988                          Pie Breakfast 2016
# 18855          Bell by Alicia Bell & Autumn Hello
# 26160                       Wendy's 50th Birthday
# 1103                            Nicole's Birthday
# 45186          Stephani's KEEP Collective Social!
# 13631                             Thinking of You
# 7075                                    Thank you
# 17244                          Valentine Luncheon
# 18462                        Happy Mother's Day!
# 38897                          Christmas Luncheon
# 6490   United Way Professional Division Kick-Off!
# 25347                              Happy Birthday
# 13622                Christine & Eric's Rehearsal
# 44563                           Happy Mothers Day
# 34385                      Mallory's 4th Birthday
# 6593                             Aimlessly Adrift
# 1776                            SWEET VALENTINE!
# 31110                           My Testing Party!
# 39568                              SAM'S BIRTHDAY
# 33609                               father's day!
# 32450     Before The Experience: Meet and Mingle
# 26126               Thank you from the Ramaswamis
# 19991                                New Address!
# 2066                                  Thank You!
# ...                                           ...
# 15949                        Myra's Having a Boy!
# 7929              Luncheon with Christine O'Brien
# 22055                         Education Reception
# 35402                                 All My Love
# 11115                    hollyhowarth@hotmail.com
# 25272                            Memorial Day BBQ
# 34947              Emily's Bridal Shower Luncheon
# 28831                       ventura6111@yahoo.com
# 12830                             Laura's Big Day
# 13819                                  Thank You!
# 2653                    Susan Hauan's Baby Shower
# 7493                       Happy Valentine's Day!
# 29442                                Card for Max
# 37350                            Henry Kim's Dohl
# 44949                       Xavier's 6th birthday
# 21333                               Friendsgiving
# 27547                                   Good luck
# 25441                              Spring Viewing
# 29978                                  thank you!
# 29245                         Divya's Baby shower
# 29357  WCHS BULLDOGS 2015 BASKETBALL TEAM BANQUET
# 29598                      Morgan's 5th birthday
# 43046                              Happy Birthday
# 7981                   Celebrate my 50th with me!
# 43608                              HAPPY BIRTHDAY
# 10751                                  Thank You!
# 12911                                  Thank you!
# 42177                    Happy Holidays from NCT!
# 26593       Lori and Titos's Hometown HoHoHo down
# 2548                      Happy Anniversary Baby!
#
#                                                     text    event_type  \
# 16106  dear noemi and family,\r\rit was so wonderful ...  GreetingCard
# 18656  devin is turning 1!\r\rplease join for a pool ...     RsvpEvent
# 385    alyse's \rbirthday \rparty\r\r\rsaturday, nove...     RsvpEvent
# 2448   nada is turning 8!nada would like to invite yo...     RsvpEvent
# 10250  dear husband,\ri love you still as if we’ve on...  GreetingCard
# 15498  celebrate\rthe\rseason\rwith\rcsc leasing comp...     RsvpEvent
# 16988  you are invited\rto our annual pie breakfast!\...     RsvpEvent
# 18855  bell by alicia bell\rcustom shirt & shirtdress...     RsvpEvent
# 26160  wendy's \r50th birthday\rsaturday, september 1...     RsvpEvent
# 1103   let's celebrate \rnicole's \rbirthday in style...     RsvpEvent
# 45186  create your one-of-a-kind at stephani robinson...     RsvpEvent
# 13631  shelley,\rthinking of you.  trust the surgery ...  GreetingCard
# 7075   thank youdear shannon,\ra very belated formal ...  GreetingCard
# 17244  lady capulet and juliet\rinvite you to join th...     RsvpEvent
# 18462  happy\rmother's day\r\rbunches and bunches of ...  GreetingCard
# 38897  eat, drink,& be merry!\r\r the chance family i...     RsvpEvent
# 6490   please join us for a\rlunch & learn\runited wa...     RsvpEvent
# 25347  dear marc\r\rhappy\rbirthday!\r\rhope this one...  GreetingCard
# 13622  let's eat! and rehearse with\rchristine & eric...     RsvpEvent
# 44563  mommy,\rhappy mother's day!  we pray you have ...  GreetingCard
# 34385  calling all critters for\rscout’s \rseventh \r...     RsvpEvent
# 6593   life is unbearable \rwithout you two rascals.....  GreetingCard
# 1776   momma & lenny:\r\rit's not a holiday without\r...  GreetingCard
# 31110  it’s jane’s big day!\rjoin us as we throw her\...     RsvpEvent
# 39568  come\rcelebrate\rsam's 35th birthday\r\rdinner...     RsvpEvent
# 33609  keep\rcalm\rand\rcall your\rpops\r\rhappy fath...  GreetingCard
# 32450  cocktails\rand\rconversation\rwith other flora...     RsvpEvent
# 26126  dear kumar mama, sunitha maami, sid, and keert...  GreetingCard
# 19991  we moved!\rthe mcketta family\r4504 west frank...  GreetingCard
# 2066   dear nolan,\r\rthank you for coming to my part...  GreetingCard
# ...                                                  ...           ...
# 15949  diapers, bibs, bottles, galore\rmyra + ryan ar...     RsvpEvent
# 7929   please join christine o'brien\r for lunch \ron...     RsvpEvent
# 22055  simmons college department of education cordia...     RsvpEvent
# 35402         you're still the one!\rlove always,\rrenée  GreetingCard
# 11115  happy birthday!\r\r\r\r\rlove you lots,\r\rhol...  GreetingCard
# 25272  guy \r& rebecca\rinvite you to\ra memorial day...     RsvpEvent
# 34947  join us for a bridal shower luncheon honoring\...     RsvpEvent
# 28831  hello husband,\rhappy 33rd birthday! i love an...  GreetingCard
# 12830  keep it quiet...\rit’s a surprise\rin honor of...     RsvpEvent
# 13819  dear betty,\rthank you for the beautiful brida...  GreetingCard
# 2653   join us for a baby shower\rin honor of\rsusan ...     RsvpEvent
# 7493   ...i just wish it was in person and not on the...  GreetingCard
# 29442              happy summer!\r\renjoy!\r\rlove,\rmom  GreetingCard
# 37350  come celebrate with us!\r saturday january 31,...     RsvpEvent
# 44949  please join us to celebrate\rxavier's 6th birt...     RsvpEvent
# 21333  i would like to thank you\rfor another wonderf...     RsvpEvent
# 27547          go walk your socks off! \ryou'll do it! x  GreetingCard
# 25441                      we hope you to see you there!     RsvpEvent
# 29978  dear maximilian,\rthank you so much for the ca...  GreetingCard
# 29245  sweet little baby is on it's way,\rjoin us on ...     RsvpEvent
# 29357  parents & players\ryou are cordially invited t...     RsvpEvent
# 29598  morgan is turning five!\rsaturday, august 22, ...     RsvpEvent
# 43046  happy birthdaygeorgia,\rhappy, happy birthday ...  GreetingCard
# 7981   " the most special celebrations are those shar...  GreetingCard
# 43608  pasy!! hoping the other 364 days\rof this year...  GreetingCard
# 10751  alex,\rthank you so much for writing my recomm...  GreetingCard
# 12911  happy holidays danielle! thank you for everyth...  GreetingCard
# 42177  may you find \rhealth, happiness and peace\rdu...  GreetingCard
# 26593  it's a\rho\rho\rho\rdown!\rplease join the bev...     RsvpEvent
# 2548   i always knew \ryou were the best!\revery year...  GreetingCard
#
#          true_primary_class    pred_primary_class  pred_primary_score  \
# 16106             greetings             greetings            0.949226
# 18656  birthday_celebration  birthday_celebration            0.961690
# 385    birthday_celebration  birthday_celebration            0.997493
# 2448   birthday_celebration  birthday_celebration            0.989731
# 10250             greetings             greetings            0.952382
# 15498         organizations              personal            0.592903
# 16988              personal              personal            0.610822
# 18855         organizations         organizations            0.413422
# 26160  birthday_celebration  birthday_celebration            0.976515
# 1103   birthday_celebration  birthday_celebration            0.972065
# 45186         organizations         organizations            0.643408
# 13631             greetings             greetings            0.951487
# 7075              greetings             greetings            0.943961
# 17244              personal              personal            0.615249
# 18462             greetings             greetings            0.957210
# 38897              personal              personal            0.656167
# 6490          organizations         organizations            0.674637
# 25347             greetings             greetings            0.990303
# 13622       wedding_related       wedding_related            0.899336
# 44563             greetings             greetings            0.964300
# 34385  birthday_celebration  birthday_celebration            0.961292
# 6593              greetings             greetings            0.806094
# 1776              greetings             greetings            0.959008
# 31110  birthday_celebration  birthday_celebration            0.964586
# 39568  birthday_celebration  birthday_celebration            0.984347
# 33609             greetings             greetings            0.936425
# 32450         organizations         organizations            0.776497
# 26126             greetings             greetings            0.949326
# 19991              personal              personal            0.710114
# 2066              greetings             greetings            0.967105
# ...                     ...                   ...                 ...
# 15949              personal              personal            0.826662
# 7929               personal         organizations            0.674041
# 22055         organizations         organizations            0.931638
# 35402             greetings             greetings            0.947429
# 11115             greetings             greetings            0.985474
# 25272              personal              personal            0.868653
# 34947       wedding_related       wedding_related            0.932446
# 28831             greetings             greetings            0.960378
# 12830  birthday_celebration  birthday_celebration            0.713475
# 13819             greetings             greetings            0.889394
# 2653               personal              personal            0.981738
# 7493              greetings             greetings            0.978847
# 29442             greetings             greetings            0.970373
# 37350  birthday_celebration  birthday_celebration            0.705619
# 44949  birthday_celebration  birthday_celebration            0.974823
# 21333              personal              personal            0.947912
# 27547             greetings             greetings            0.876828
# 25441         organizations              personal            0.490540
# 29978             greetings             greetings            0.965152
# 29245              personal              personal            0.994086
# 29357         organizations         organizations            0.879553
# 29598  birthday_celebration  birthday_celebration            0.965391
# 43046             greetings             greetings            0.999545
# 7981   birthday_celebration  birthday_celebration            0.681867
# 43608             greetings             greetings            0.935849
# 10751             greetings             greetings            0.926721
# 12911             greetings             greetings            0.977126
# 42177             greetings             greetings            0.954195
# 26593              personal              personal            0.577710
# 2548              greetings             greetings            0.593728
#
#                                     true_secondary_class  \
# 16106                                 everyday_greetings
# 18656                                      kids_birthday
# 385                                              general
# 2448                                       kids_birthday
# 10250                                 everyday_greetings
# 15498                             business_or_nonprofits
# 16988                               other_holiday_events
# 18855                             business_or_nonprofits
# 26160                                     adult_birthday
# 1103                                      adult_birthday
# 45186                             business_or_nonprofits
# 13631                                 everyday_greetings
# 7075                                  everyday_greetings
# 17244                               other_holiday_events
# 18462                                other_holiday_cards
# 38897                            seasonal_holiday_events
# 6490                              business_or_nonprofits
# 25347                                 everyday_greetings
# 13622     wedding_events_hosted_by_bride_groom_or_family
# 44563                                other_holiday_cards
# 34385                                      kids_birthday
# 6593                                  everyday_greetings
# 1776                                 other_holiday_cards
# 31110                                      kids_birthday
# 39568                                     adult_birthday
# 33609                                other_holiday_cards
# 32450                             business_or_nonprofits
# 26126                                 everyday_greetings
# 19991                             announcements_personal
# 2066                                  everyday_greetings
# ...                                                  ...
# 15949             celebrating_baby_kids_or_parents_to_be
# 7929                              adult_or_family_events
# 22055                           alumni_or_school_related
# 35402                                 everyday_greetings
# 11115                                 everyday_greetings
# 25272                               other_holiday_events
# 34947  parties_and_showers_in_honor_of_the_bride_&_groom
# 28831                                 everyday_greetings
# 12830                                     adult_birthday
# 13819                                 everyday_greetings
# 2653              celebrating_baby_kids_or_parents_to_be
# 7493                                 other_holiday_cards
# 29442                                 everyday_greetings
# 37350                                      kids_birthday
# 44949                                      kids_birthday
# 21333                               other_holiday_events
# 27547                                 everyday_greetings
# 25441                             business_or_nonprofits
# 29978                                 everyday_greetings
# 29245             celebrating_baby_kids_or_parents_to_be
# 29357                           alumni_or_school_related
# 29598                                      kids_birthday
# 43046                                 everyday_greetings
# 7981                                      adult_birthday
# 43608                                 everyday_greetings
# 10751                                 everyday_greetings
# 12911                             seasonal_holiday_cards
# 42177                             seasonal_holiday_cards
# 26593                            seasonal_holiday_events
# 2548                                  everyday_greetings
#
#                          true_tertiary_class
# 16106                              thank_you
# 18656                     1st_birthday_party
# 385                   general_birthday_party
# 2448               tween_8_12_birthday_party
# 10250                               birthday
# 15498                          holiday_party
# 16988                           thanksgiving
# 18855                        marketing_event
# 26160         adult_milestone_birthday_party
# 1103              other_adult_birthday_party
# 45186                        marketing_event
# 13631                   love_or_just_because
# 7075                               thank_you
# 17244                             valentines
# 18462                            mothers_day
# 38897                              christmas
# 6490             fundraiser_or_charity_event
# 25347                               birthday
# 13622                        rehearsal_event
# 44563                            mothers_day
# 34385         little_kids_2_7_birthday_party
# 6593                    love_or_just_because
# 1776                              valentines
# 31110              teen_13_18_birthday_party
# 39568         adult_milestone_birthday_party
# 33609                            fathers_day
# 32450                     reception_or_party
# 26126                              thank_you
# 19991                    moving_announcement
# 2066                               thank_you
# ...                                      ...
# 15949  baby_shower_or_new_baby_related_event
# 7929           general_party_food_and_drinks
# 22055                 faculty_or_staff_event
# 35402                   love_or_just_because
# 11115                               birthday
# 25272                       other_us_holiday
# 34947                         wedding_shower
# 28831                               birthday
# 12830             other_adult_birthday_party
# 13819                              thank_you
# 2653   baby_shower_or_new_baby_related_event
# 7493                              valentines
# 29442                   love_or_just_because
# 37350                     1st_birthday_party
# 44949         little_kids_2_7_birthday_party
# 21333                           thanksgiving
# 27547                              good_luck
# 25441                        marketing_event
# 29978                              thank_you
# 29245  baby_shower_or_new_baby_related_event
# 29357   other_alumni_or_school_related_event
# 29598         little_kids_2_7_birthday_party
# 43046                               birthday
# 7981          adult_milestone_birthday_party
# 43608                               birthday
# 10751                              thank_you
# 12911                                holiday
# 42177                                holiday
# 26593                                holiday
# 2548                             anniversary
#
# [18508 rows x 8 columns]

# %%
y = df['true_secondary_class']
X = df[['subject','text','event_type','pred_primary_class','pred_primary_score']]

# %%
import os
import time
from collections import Counter
import logging
import argparse

# helper modules
from ml_utils import pickle_classifier, load_classifier, ExtractFeature, \
                     precision_recall_matrix, get_classifier_results
from nlp_helper import CleanTextTransformer, tokenize_text
from query_events import execute_query

import pandas as pd
import numpy as np

from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer


from scipy.sparse import coo_matrix, hstack

# %%
id_num = 674

# %%
X.head()
# Out:
#                              subject  \
# 16106               Thank you, Noemi
# 18656         Devin's First Birthday
# 385    Alyse Bowser's Birthday Party
# 2448             Nada's 8th Birthday
# 10250            To someone special
#
#                                                     text    event_type  \
# 16106  dear noemi and family,\r\rit was so wonderful ...  GreetingCard
# 18656  devin is turning 1!\r\rplease join for a pool ...     RsvpEvent
# 385    alyse's \rbirthday \rparty\r\r\rsaturday, nove...     RsvpEvent
# 2448   nada is turning 8!nada would like to invite yo...     RsvpEvent
# 10250  dear husband,\ri love you still as if we’ve on...  GreetingCard
#
#          pred_primary_class  pred_primary_score
# 16106             greetings            0.949226
# 18656  birthday_celebration            0.961690
# 385    birthday_celebration            0.997493
# 2448   birthday_celebration            0.989731
# 10250             greetings            0.952382

# %%
# split training, testing
x_train, x_test, y_train, y_test, idx1, idx2 = train_test_split(X, y, X.index, test_size=0.4)

# %%
x_train_matrix, feature_pipeline = get_secondary_training_features(x_train, y_train, FEATURE_PIPELINE)
x_test_matrix = get_secondary_testing_features(x_test, feature_pipeline)
# Out:
# Beginning pipeline fit_transform to training data...
# Completed fit_transform
# Training set dimension: (11104, 38529)
# Beginning transform of test set...
# Completed transform of test set.
# Testing set dimension: (7404, 38529)

# %%
y_tertiary = df.true_tertiary_class[idx2]

# %%
save_secondary_features(feature_pipeline, 'secondary', id_num)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-124-b8751729d633> in <module>()
# ----> 1 save_secondary_features(feature_pipeline, 'secondary', id_num)
#
# <ipython-input-123-86c5fdce146d> in save_secondary_features(feature_pipeline, level, id_num)
#       7
#       8     logger.info("Saving secondaryfitted feature pipeline id {}...".format(id_num))
# ----> 9     pickle_classifier(feature_pipeline, FEATURE_DIR + level + "_" + str(id_num))
#      10
#      11     return id_num
#
# NameError: name 'FEATURE_DIR' is not defined

# %%
x_train_matrix
# Out:
# <11104x38529 sparse matrix of type '<class 'numpy.float64'>'
# 	with 269136 stored elements in COOrdinate format>

# %%
y_train.value_counts()
# Out:
# everyday_greetings                                   2464
# kids_birthday                                        1674
# adult_birthday                                        975
# business_or_nonprofits                                972
# adult_or_family_events                                963
# celebrating_baby_kids_or_parents_to_be                625
# parties_and_showers_in_honor_of_the_bride_&_groom     525
# seasonal_holiday_cards                                437
# seasonal_holiday_events                               398
# other_holiday_cards                                   390
# wedding_events_hosted_by_bride_groom_or_family        364
# other_holiday_events                                  312
# alumni_or_school_related                              249
# save_the_date                                         228
# foreign_language                                      190
# wedding_related_other                                 147
# general                                                72
# announcements_personal                                 67
# other                                                  42
# announcements_wedding_related                           8
# address_collection                                      2
# Name: true_secondary_class, dtype: int64

# %%
clf_list, clf_names = grid_search(x_train_matrix, y_train, CLASSIFIER_PIPELINE)
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# /usr/local/lib/python3.6/site-packages/sklearn/model_selection/_split.py:581: Warning: The least populated class in y has only 2 members, which is too few. The minimum number of groups for any class cannot be less than n_splits=3.
#   % (min_groups, self.n_splits)), Warning)
# [CV] clf__C=1, clf__kernel=linear ....................................
# [CV] clf__C=1, clf__kernel=linear ....................................
# [CV] clf__C=1, clf__kernel=linear ....................................
# [CV] ..................... clf__C=1, clf__kernel=linear, total=  55.8s
# [CV] ..................... clf__C=1, clf__kernel=linear, total=  57.0s
# [CV] ..................... clf__C=1, clf__kernel=linear, total=  57.4s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:  1.2min finished

# %%
results, classes = get_classifier_results(clf_list, clf_names, x_test_matrix, y_test)
# Out:
# Getting classifier results...

# %%
save_classifier(clf_list, 'secondary', id_num)
# Out:
# Saving classifier: /Users/iman/code/event_classifier/model/pickles/classifiers/secondary_classifier_674...

# %%
y_pred, y_score = get_ensemble_prediction(results, classes)
_check_prediction_dimensions(y_test, y_pred, y_score)
# Out:
# Getting ensemble predictions...

# %%
def _decorate_with_secondary(X, y_test, y_pred, y_score, y_tertiary):
    """
    Adds two columns to x_test
        predicted primary class
        predicted primary score
    Used as input to secondary classifier
    """

    # uses output of primary model
    X['true_secondary_class'] = y_test
    X['pred_secondary_class'] = y_pred
    X['pred_secondary_score'] = y_score
    X['true_tertiary_class'] = y_tertiary


    return X

# %%
y_tertiary = df.true_tertiary_class[idx2]

# %%
_decorate_with_secondary(x_test, y_test, y_pred, y_score, y_tertiary)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
#                                               subject  \
# 4003                                         Wedding
# 38188                                Merry Christmas!
# 38913                        Sebastian's 3rd Birthday
# 16224                             Kay Lee Invitation
# 4693                Dawn Brown-Piatt's Wedding Shower
# 1958                                 Fredi's Birthday
# 3541                      Happy Birthday Little Lady!
# 9657                                   Halloween Fête
# 3991                  Mischa and Amelia are turning 8
# 40976                       Katherine's Bridal Shower
# 11571                                        Birthday
# 20437                                 Char's Birthday
# 40321            Summer's Bridal Shower Napa Edition
# 3377                           Melissa's Farewell (1)
# 31097                                  Light the Path
# 7334               Josh Rosner and Nina Ragaz Wedding
# 37734                             MARIA'S BABY SHOWER
# 39875                       Lillian's Third Birthday!
# 8838                              BIG BUSINESS LAUNCH
# 32256                               Evening reception
# 35160                                              XO
# 12148  Newly Tenured & Promoted Faculty Reception (1)
# 13197              Liberty Lunch: Policing the Police
# 37338                                      Thank you!
# 25224               Greg and Shadi's Engagement Party
# 4288                         Thanks (turn card over!)
# 34323                               Happy Birthday!!!
# 29000                          Eric Saari annual gala
# 21463               Bubbly, Chocolate & Beautycounter
# 45868          Meghal's Birthday Celebration 01.14.17
# ...                                               ...
# 16804                  A Toast to the Bride and Groom
# 42931                 Liberty Hill Housewarming Party
# 29567                                          Brunch
# 1544                       Natalie's First Communion
# 8033                            Baker's 2nd Birthday!
# 21950                              Holiday Trunk Show
# 41343            A Most Wonderful Of Birthdays...Xoxo
# 40560              Susan & Daniel Destination Wedding
# 19591                    Caroline's Graduation Party!
# 25432                                  Thank You Card
# 36947                                  Lawson Hanukka
# 14564                   Nataly & Richard Baby Shower
# 42691                                  Save the date!
# 9574         Preferred Children's Services Open House
# 20705                                  Happy Birthday
# 36572                                            Hubs
# 5368                    Summer BBQ & Children's Party
# 5390                                Beau & Dean's 5th
# 37744                             Happy Mother's Day!
# 3636                  Palmyra-Macedon's Class of 1985
# 19259                      Biddy's Birthday Breakfast
# 31745                                        BIRTHDAY
# 34474                             Happy Mother's Day!
# 30927                                     Mothers Day
# 41826                                  Thank you (20)
# 26178              Millie's Birthday Party INVITATION
# 17196                        K.C.'s Birthday Barbeque
# 9673                         Nathalie's 1st Birthday!
# 16254                          Eliza's Birthday Party
# 28151   Car lovers dream - complimentary happy hour!
#
#                                                     text         event_type  \
# 4003   will you be my\rbridesmaid?\rdear lou, i could...       GreetingCard
# 38188  dear roland and susan,\ri hope you have a very...       GreetingCard
# 38913  sebastian's 3rd birthday\rsunday, january 29th...          RsvpEvent
# 16224  kay lee invites you for a glass of wine and to...          RsvpEvent
# 4693   directions to leigh beauchamp's home:\r\rtruma...          RsvpEvent
# 1958   rumour has it\r   fredi prevost\ris turning 50...          RsvpEvent
# 3541   have a slice (or two):\rit's your birthday. \r...       GreetingCard
# 9657   you are invited to a\rhalloween fete\rthe spoo...          RsvpEvent
# 3991   come and celebrate \ramelia and mischa  turnin...          RsvpEvent
# 40976  join us for a bridal shower to celebrate\rkath...          RsvpEvent
# 11571  dear leo,\r\rwe just wanted to send you great ...       GreetingCard
# 20437  char’s partychar is turning 27!\rcome celebrat...          RsvpEvent
# 40321  summer’s getting hitched!\rhelp us toast her a...          RsvpEvent
# 3377   please join us to bid farewell to\r\rmelissa b...          RsvpEvent
# 31097  please join us for\rdinner\rand\rdrinks\r the ...          RsvpEvent
# 7334   josh rosner\rand\rnina ragaz\rrequest your pre...          RsvpEvent
# 37734  please join us for a baby shower\rin honor of\...          RsvpEvent
# 39875  lillian's\r\r\rsaturday, may 16th 4:00 pm\r\r\...          RsvpEvent
# 8838   you are invited\rto celebrate\rveronica trujil...          RsvpEvent
# 32256  together with\rtheir families\r\rgosia\rmarcin...          RsvpEvent
# 35160  i'm truly sorry if i disappointed you steph.  ...       GreetingCard
# 12148  president lee pelton\rinvites you and a guest ...          RsvpEvent
# 13197  terri burke and the aclu of texas\rinvite you ...          RsvpEvent
# 37338  thank you\r\r\r\r\r\r\r\r\r\rdear wendy,\r\rth...       GreetingCard
# 25224  to ring in\rgreg & shadi’s\rengagement\r\rsatu...          RsvpEvent
# 4288   aw shucks, \ryou shouldn't have.jermaine,\rtha...       GreetingCard
# 34323  it’s\ryour\rday!\r\rhappy 35th!\reven in aspen...       GreetingCard
# 29000  please join\rthe davis family\rfor a holiday p...          RsvpEvent
# 21463  please join us for\ra little bubbly, chocolate...          RsvpEvent
# 45868  shh...its a surprise\rcome celebrate meghal's ...          RsvpEvent
# ...                                                  ...                ...
# 16804  the night before celebration\r\rjoin us  for d...          RsvpEvent
# 42931  please join \rmeridith and carrie \rfor a \rho...          RsvpEvent
# 29567  please join us for brunch as we\rcelebrate and...          RsvpEvent
# 1544   please join us as we celebrate \rthe first com...          RsvpEvent
# 8033   you’re invited to celebrate\rbaker's\r2nd birt...          RsvpEvent
# 21950  hosted by :﻿\rarcherelle collection\r\rcommuni...          RsvpEvent
# 41343  dear mom,\r\rhoping the other\r364 days of thi...       GreetingCard
# 40560  daniel & susan \rrequest the pleasure of your ...          RsvpEvent
# 19591  join us for brunch to celebrate the graduate\r...          RsvpEvent
# 25432  dear michelle,\r\rthank you so much for the th...       GreetingCard
# 36947  it's been too long!\rlets revive the lawson ha...          RsvpEvent
# 14564  nataly & richard \rbaby shower\r\rnos gustaría...          RsvpEvent
# 42691  lianne + paul\r\r\r\rare getting married\r\r\r...  DatedAnnouncement
# 9574   please join us in celebrating the\r\r\r\ropen ...          RsvpEvent
# 20705  colin, \rwow, you are officially an antique!  ...       GreetingCard
# 36572  hubs\r\rthank you for a wonderful mothers day\...       GreetingCard
# 5368                                                              RsvpEvent
# 5390   please come celebrate!\r beau & dean \rare tur...          RsvpEvent
# 37744  mom,\r\rtreat yourself to \rsomething sweet to...       GreetingCard
# 3636   friday\r\rto be announced ;)palmyra-macedon's\...          RsvpEvent
# 19259  biddy's 60th birthday\rplease join us for a bi...          RsvpEvent
# 31745  jump around!\r\r\rkarin's\rbirthday\r\r\r\r\r\...          RsvpEvent
# 34474  dear mom,\ri am blessed to have grown up in th...       GreetingCard
# 30927  mom,\rthank you for always being there. happy ...       GreetingCard
# 41826  thank you so much for coming to the wedding an...       GreetingCard
# 26178  join us for a birthday bbq\rwhen: saturday jul...       GreetingCard
# 17196  k.c. du fay invites you to a\rbirthday barbecu...          RsvpEvent
# 9673   nathalie's 1st birthday!\rwe did it! come cele...          RsvpEvent
# 16254  todd kraines & george glass\rinvite you to\r\r...          RsvpEvent
# 28151  date: tuesday, june 16th\rtime: 6:00-8:00pm\rl...          RsvpEvent
#
#          pred_primary_class  pred_primary_score  \
# 4003        wedding_related            0.813043
# 38188             greetings            0.945836
# 38913  birthday_celebration            0.967542
# 16224         organizations            0.667299
# 4693        wedding_related            0.869356
# 1958   birthday_celebration            0.996912
# 3541              greetings            0.990787
# 9657               personal            0.890758
# 3991   birthday_celebration            0.951438
# 40976       wedding_related            0.956258
# 11571  birthday_celebration            0.515358
# 20437  birthday_celebration            0.956336
# 40321       wedding_related            0.842825
# 3377               personal            0.798660
# 31097              personal            0.639156
# 7334        wedding_related            0.949025
# 37734              personal            0.970706
# 39875  birthday_celebration            0.930841
# 8838          organizations            0.834381
# 32256         organizations            0.507901
# 35160             greetings            0.925763
# 12148         organizations            0.843940
# 13197         organizations            0.660902
# 37338             greetings            0.971404
# 25224       wedding_related            0.930271
# 4288              greetings            0.982857
# 34323             greetings            0.986711
# 29000              personal            0.942248
# 21463         organizations            0.440534
# 45868  birthday_celebration            0.995362
# ...                     ...                 ...
# 16804       wedding_related            0.513396
# 42931              personal            0.840988
# 29567              personal            0.725282
# 1544               personal            0.767075
# 8033   birthday_celebration            0.971334
# 21950         organizations            0.897355
# 41343             greetings            0.956787
# 40560       wedding_related            0.854908
# 19591              personal            0.896191
# 25432             greetings            0.809109
# 36947              personal            0.566455
# 14564              personal            0.888522
# 42691       wedding_related            0.909381
# 9574          organizations            0.636697
# 20705             greetings            0.993089
# 36572             greetings            0.896444
# 5368               personal            0.664435
# 5390   birthday_celebration            0.964231
# 37744             greetings            0.963877
# 3636          organizations            0.897180
# 19259  birthday_celebration            0.965808
# 31745  birthday_celebration            0.990808
# 34474             greetings            0.973710
# 30927             greetings            0.943461
# 41826             greetings            0.882491
# 26178  birthday_celebration            0.921009
# 17196  birthday_celebration            0.894796
# 9673   birthday_celebration            0.983883
# 16254  birthday_celebration            0.953654
# 28151         organizations            0.825682
#
#                                     true_secondary_class  \
# 4003                               wedding_related_other
# 38188                             seasonal_holiday_cards
# 38913                                      kids_birthday
# 16224                             business_or_nonprofits
# 4693   parties_and_showers_in_honor_of_the_bride_&_groom
# 1958                                      adult_birthday
# 3541                                  everyday_greetings
# 9657                                other_holiday_events
# 3991                                       kids_birthday
# 40976  parties_and_showers_in_honor_of_the_bride_&_groom
# 11571                                 everyday_greetings
# 20437                                     adult_birthday
# 40321  parties_and_showers_in_honor_of_the_bride_&_groom
# 3377                              adult_or_family_events
# 31097                             business_or_nonprofits
# 7334      wedding_events_hosted_by_bride_groom_or_family
# 37734             celebrating_baby_kids_or_parents_to_be
# 39875                                      kids_birthday
# 8838                              adult_or_family_events
# 32256     wedding_events_hosted_by_bride_groom_or_family
# 35160                                 everyday_greetings
# 12148                           alumni_or_school_related
# 13197                             business_or_nonprofits
# 37338                                 everyday_greetings
# 25224  parties_and_showers_in_honor_of_the_bride_&_groom
# 4288                                  everyday_greetings
# 34323                                 everyday_greetings
# 29000                            seasonal_holiday_events
# 21463                             business_or_nonprofits
# 45868                                     adult_birthday
# ...                                                  ...
# 16804     wedding_events_hosted_by_bride_groom_or_family
# 42931                             adult_or_family_events
# 29567                               other_holiday_events
# 1544              celebrating_baby_kids_or_parents_to_be
# 8033                                       kids_birthday
# 21950                            seasonal_holiday_events
# 41343                                 everyday_greetings
# 40560     wedding_events_hosted_by_bride_groom_or_family
# 19591                             adult_or_family_events
# 25432                                 everyday_greetings
# 36947                                other_holiday_cards
# 14564             celebrating_baby_kids_or_parents_to_be
# 42691                                      save_the_date
# 9574                              business_or_nonprofits
# 20705                                 everyday_greetings
# 36572                                 everyday_greetings
# 5368                              adult_or_family_events
# 5390                                       kids_birthday
# 37744                                other_holiday_cards
# 3636                            alumni_or_school_related
# 19259                                     adult_birthday
# 31745                                     adult_birthday
# 34474                                other_holiday_cards
# 30927                                other_holiday_cards
# 41826                              wedding_related_other
# 26178                                      kids_birthday
# 17196                                     adult_birthday
# 9673                                       kids_birthday
# 16254                                      kids_birthday
# 28151                             business_or_nonprofits
#
#                                     pred_secondary_class  \
# 4003                               wedding_related_other
# 38188                             seasonal_holiday_cards
# 38913                                      kids_birthday
# 16224                             business_or_nonprofits
# 4693   parties_and_showers_in_honor_of_the_bride_&_groom
# 1958                                      adult_birthday
# 3541                                  everyday_greetings
# 9657                                other_holiday_events
# 3991                                       kids_birthday
# 40976  parties_and_showers_in_honor_of_the_bride_&_groom
# 11571                                 everyday_greetings
# 20437                                     adult_birthday
# 40321  parties_and_showers_in_honor_of_the_bride_&_groom
# 3377                              adult_or_family_events
# 31097                             adult_or_family_events
# 7334      wedding_events_hosted_by_bride_groom_or_family
# 37734             celebrating_baby_kids_or_parents_to_be
# 39875                                      kids_birthday
# 8838                              business_or_nonprofits
# 32256                             business_or_nonprofits
# 35160                                 everyday_greetings
# 12148                             business_or_nonprofits
# 13197                             business_or_nonprofits
# 37338                                 everyday_greetings
# 25224  parties_and_showers_in_honor_of_the_bride_&_groom
# 4288                                  everyday_greetings
# 34323                                 everyday_greetings
# 29000                            seasonal_holiday_events
# 21463                             business_or_nonprofits
# 45868                                     adult_birthday
# ...                                                  ...
# 16804  parties_and_showers_in_honor_of_the_bride_&_groom
# 42931                             adult_or_family_events
# 29567                             adult_or_family_events
# 1544              celebrating_baby_kids_or_parents_to_be
# 8033                                       kids_birthday
# 21950                             business_or_nonprofits
# 41343                                 everyday_greetings
# 40560     wedding_events_hosted_by_bride_groom_or_family
# 19591                             adult_or_family_events
# 25432                                 everyday_greetings
# 36947                             adult_or_family_events
# 14564             celebrating_baby_kids_or_parents_to_be
# 42691                                      save_the_date
# 9574                              business_or_nonprofits
# 20705                                 everyday_greetings
# 36572                                 everyday_greetings
# 5368                              adult_or_family_events
# 5390                                       kids_birthday
# 37744                                other_holiday_cards
# 3636                            alumni_or_school_related
# 19259                                            general
# 31745                                      kids_birthday
# 34474                                other_holiday_cards
# 30927                                other_holiday_cards
# 41826                                 everyday_greetings
# 26178                                      kids_birthday
# 17196                                     adult_birthday
# 9673                                       kids_birthday
# 16254                                      kids_birthday
# 28151                             business_or_nonprofits
#
#        pred_secondary_score                        true_tertiary_class
# 4003               0.853052                      other_wedding_related
# 38188              0.968027                                  christmas
# 38913              0.982516             little_kids_2_7_birthday_party
# 16224              0.821835  trunk_show_or_shopping_or_marketing_event
# 4693               0.702263                             wedding_shower
# 1958               0.857333                 other_adult_birthday_party
# 3541               0.970410                                   birthday
# 9657               0.907173                                  halloween
# 3991               0.995628                  tween_8_12_birthday_party
# 40976              0.988883                             wedding_shower
# 11571              0.933032                                   birthday
# 20437              0.808111                 other_adult_birthday_party
# 40321              0.987456                             wedding_shower
# 3377               0.831355                         farewell_or_moving
# 31097              0.379875           formal_reception_dinner_or_party
# 7334               0.949970                         wedding_invitation
# 37734              0.981363      baby_shower_or_new_baby_related_event
# 39875              0.750371             little_kids_2_7_birthday_party
# 8838               0.883404              general_party_food_and_drinks
# 32256              0.583802                         wedding_invitation
# 35160              0.825340                                    apology
# 12148              0.652492                     faculty_or_staff_event
# 13197              0.709675              meeting_lecture_or_networking
# 37338              0.979808                                  thank_you
# 25224              0.981902                           engagement_party
# 4288               0.935328                                  thank_you
# 34323              0.985818                                   birthday
# 29000              0.927813                                    holiday
# 21463              0.731393  trunk_show_or_shopping_or_marketing_event
# 45868              0.944536                 other_adult_birthday_party
# ...                     ...                                        ...
# 16804              0.585715                        night_before_drinks
# 42931              0.800047                               housewarming
# 29567              0.656237                               thanksgiving
# 1544               0.908694                         religious_ceremony
# 8033               0.993757             little_kids_2_7_birthday_party
# 21950              0.932762                                    holiday
# 41343              0.931566                                   birthday
# 40560              0.889782                         wedding_invitation
# 19591              0.831892                                 graduation
# 25432              0.976831                                  thank_you
# 36947              0.305212                                   hanukkah
# 14564              0.954347      baby_shower_or_new_baby_related_event
# 42691              0.978061                      wedding_save_the_date
# 9574               0.520142                            marketing_event
# 20705              0.978733                                  thank_you
# 36572              0.426422                                  thank_you
# 5368               0.726030              general_party_food_and_drinks
# 5390               0.987050             little_kids_2_7_birthday_party
# 37744              0.963607                                mothers_day
# 3636               0.970158                                    reunion
# 19259              0.578985             adult_milestone_birthday_party
# 31745              0.513210                 other_adult_birthday_party
# 34474              0.961652                                mothers_day
# 30927              0.926879                                mothers_day
# 41826              0.949814                          wedding_thank_you
# 26178              0.787839             little_kids_2_7_birthday_party
# 17196              0.545204                 other_adult_birthday_party
# 9673               0.972327                         1st_birthday_party
# 16254              0.875724                  other_kids_birthday_party
# 28151              0.592209                      casual_drinks_or_food
#
# [7404 rows x 9 columns]

# %%
hierarchy.head()
# Out:
#            p_class                                            s_class  \
# 0        greetings                                 everyday_greetings
# 1         personal                            seasonal_holiday_events
# 2  wedding_related  parties_and_showers_in_honor_of_the_bride_&_groom
# 3        greetings                                 everyday_greetings
# 4        greetings                                other_holiday_cards
#
#                 t_class
# 0             thank_you
# 1             christmas
# 2        wedding_shower
# 3              birthday
# 4  other_muslim_holiday

# %%
df = execute_query(QUERY_ALL)
hierarchy = df[['p_class', 's_class', 't_class']].drop_duplicates()

# %%
x_test.head()
# Out:
#                                  subject  \
# 4003                            Wedding
# 38188                   Merry Christmas!
# 38913           Sebastian's 3rd Birthday
# 16224                Kay Lee Invitation
# 4693   Dawn Brown-Piatt's Wedding Shower
#
#                                                     text    event_type  \
# 4003   will you be my\rbridesmaid?\rdear lou, i could...  GreetingCard
# 38188  dear roland and susan,\ri hope you have a very...  GreetingCard
# 38913  sebastian's 3rd birthday\rsunday, january 29th...     RsvpEvent
# 16224  kay lee invites you for a glass of wine and to...     RsvpEvent
# 4693   directions to leigh beauchamp's home:\r\rtruma...     RsvpEvent
#
#          pred_primary_class  pred_primary_score  \
# 4003        wedding_related            0.813043
# 38188             greetings            0.945836
# 38913  birthday_celebration            0.967542
# 16224         organizations            0.667299
# 4693        wedding_related            0.869356
#
#                                     true_secondary_class  \
# 4003                               wedding_related_other
# 38188                             seasonal_holiday_cards
# 38913                                      kids_birthday
# 16224                             business_or_nonprofits
# 4693   parties_and_showers_in_honor_of_the_bride_&_groom
#
#                                     pred_secondary_class  \
# 4003                               wedding_related_other
# 38188                             seasonal_holiday_cards
# 38913                                      kids_birthday
# 16224                             business_or_nonprofits
# 4693   parties_and_showers_in_honor_of_the_bride_&_groom
#
#        pred_secondary_score                        true_tertiary_class
# 4003               0.853052                      other_wedding_related
# 38188              0.968027                                  christmas
# 38913              0.982516             little_kids_2_7_birthday_party
# 16224              0.821835  trunk_show_or_shopping_or_marketing_event
# 4693               0.702263                             wedding_shower

# %%
def _enforce_hierarchy(row):
    
    primary, secondary, p_score, s_score = row['pred_primary_class'], row['pred_secondary_class'], row['pred_primary_score'], row['pred_secondary_score']
        
    expected_primary = np.unique(hierarchy[hierarchy.s_class == secondary].p_class)
    
    if expected_primary == primary:
        "Secondary hierarchy enforced"
        return primary, secondary
    else:
        if p_score > s_score:  # primary wins
            return primary, 'unknown'
        else:
            return expected_primary, secondary

# %%
def add_final_classes(X):
    """
    Enforce the hierarchy and add final classification
    """

    print("Adding final classifications to dataframe...")
    finals = X.apply(_enforce_hierarchy, axis=1)
    finals = np.array([np.array([i[0], i[1]]) for i in finals])

    X.loc[:, 'final_primary'] = finals[:, 0]
    X.loc[:, 'final_secondary'] = finals[:, 1]

    return X

# %%
final_x = add_final_classes(x_test)
# Out:
# Adding final classifications to dataframe...
# /usr/local/lib/python3.6/site-packages/pandas/core/indexing.py:337: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /usr/local/lib/python3.6/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
final_x
# Out:
#                                               subject  \
# 4003                                         Wedding
# 38188                                Merry Christmas!
# 38913                        Sebastian's 3rd Birthday
# 16224                             Kay Lee Invitation
# 4693                Dawn Brown-Piatt's Wedding Shower
# 1958                                 Fredi's Birthday
# 3541                      Happy Birthday Little Lady!
# 9657                                   Halloween Fête
# 3991                  Mischa and Amelia are turning 8
# 40976                       Katherine's Bridal Shower
# 11571                                        Birthday
# 20437                                 Char's Birthday
# 40321            Summer's Bridal Shower Napa Edition
# 3377                           Melissa's Farewell (1)
# 31097                                  Light the Path
# 7334               Josh Rosner and Nina Ragaz Wedding
# 37734                             MARIA'S BABY SHOWER
# 39875                       Lillian's Third Birthday!
# 8838                              BIG BUSINESS LAUNCH
# 32256                               Evening reception
# 35160                                              XO
# 12148  Newly Tenured & Promoted Faculty Reception (1)
# 13197              Liberty Lunch: Policing the Police
# 37338                                      Thank you!
# 25224               Greg and Shadi's Engagement Party
# 4288                         Thanks (turn card over!)
# 34323                               Happy Birthday!!!
# 29000                          Eric Saari annual gala
# 21463               Bubbly, Chocolate & Beautycounter
# 45868          Meghal's Birthday Celebration 01.14.17
# ...                                               ...
# 16804                  A Toast to the Bride and Groom
# 42931                 Liberty Hill Housewarming Party
# 29567                                          Brunch
# 1544                       Natalie's First Communion
# 8033                            Baker's 2nd Birthday!
# 21950                              Holiday Trunk Show
# 41343            A Most Wonderful Of Birthdays...Xoxo
# 40560              Susan & Daniel Destination Wedding
# 19591                    Caroline's Graduation Party!
# 25432                                  Thank You Card
# 36947                                  Lawson Hanukka
# 14564                   Nataly & Richard Baby Shower
# 42691                                  Save the date!
# 9574         Preferred Children's Services Open House
# 20705                                  Happy Birthday
# 36572                                            Hubs
# 5368                    Summer BBQ & Children's Party
# 5390                                Beau & Dean's 5th
# 37744                             Happy Mother's Day!
# 3636                  Palmyra-Macedon's Class of 1985
# 19259                      Biddy's Birthday Breakfast
# 31745                                        BIRTHDAY
# 34474                             Happy Mother's Day!
# 30927                                     Mothers Day
# 41826                                  Thank you (20)
# 26178              Millie's Birthday Party INVITATION
# 17196                        K.C.'s Birthday Barbeque
# 9673                         Nathalie's 1st Birthday!
# 16254                          Eliza's Birthday Party
# 28151   Car lovers dream - complimentary happy hour!
#
#                                                     text         event_type  \
# 4003   will you be my\rbridesmaid?\rdear lou, i could...       GreetingCard
# 38188  dear roland and susan,\ri hope you have a very...       GreetingCard
# 38913  sebastian's 3rd birthday\rsunday, january 29th...          RsvpEvent
# 16224  kay lee invites you for a glass of wine and to...          RsvpEvent
# 4693   directions to leigh beauchamp's home:\r\rtruma...          RsvpEvent
# 1958   rumour has it\r   fredi prevost\ris turning 50...          RsvpEvent
# 3541   have a slice (or two):\rit's your birthday. \r...       GreetingCard
# 9657   you are invited to a\rhalloween fete\rthe spoo...          RsvpEvent
# 3991   come and celebrate \ramelia and mischa  turnin...          RsvpEvent
# 40976  join us for a bridal shower to celebrate\rkath...          RsvpEvent
# 11571  dear leo,\r\rwe just wanted to send you great ...       GreetingCard
# 20437  char’s partychar is turning 27!\rcome celebrat...          RsvpEvent
# 40321  summer’s getting hitched!\rhelp us toast her a...          RsvpEvent
# 3377   please join us to bid farewell to\r\rmelissa b...          RsvpEvent
# 31097  please join us for\rdinner\rand\rdrinks\r the ...          RsvpEvent
# 7334   josh rosner\rand\rnina ragaz\rrequest your pre...          RsvpEvent
# 37734  please join us for a baby shower\rin honor of\...          RsvpEvent
# 39875  lillian's\r\r\rsaturday, may 16th 4:00 pm\r\r\...          RsvpEvent
# 8838   you are invited\rto celebrate\rveronica trujil...          RsvpEvent
# 32256  together with\rtheir families\r\rgosia\rmarcin...          RsvpEvent
# 35160  i'm truly sorry if i disappointed you steph.  ...       GreetingCard
# 12148  president lee pelton\rinvites you and a guest ...          RsvpEvent
# 13197  terri burke and the aclu of texas\rinvite you ...          RsvpEvent
# 37338  thank you\r\r\r\r\r\r\r\r\r\rdear wendy,\r\rth...       GreetingCard
# 25224  to ring in\rgreg & shadi’s\rengagement\r\rsatu...          RsvpEvent
# 4288   aw shucks, \ryou shouldn't have.jermaine,\rtha...       GreetingCard
# 34323  it’s\ryour\rday!\r\rhappy 35th!\reven in aspen...       GreetingCard
# 29000  please join\rthe davis family\rfor a holiday p...          RsvpEvent
# 21463  please join us for\ra little bubbly, chocolate...          RsvpEvent
# 45868  shh...its a surprise\rcome celebrate meghal's ...          RsvpEvent
# ...                                                  ...                ...
# 16804  the night before celebration\r\rjoin us  for d...          RsvpEvent
# 42931  please join \rmeridith and carrie \rfor a \rho...          RsvpEvent
# 29567  please join us for brunch as we\rcelebrate and...          RsvpEvent
# 1544   please join us as we celebrate \rthe first com...          RsvpEvent
# 8033   you’re invited to celebrate\rbaker's\r2nd birt...          RsvpEvent
# 21950  hosted by :﻿\rarcherelle collection\r\rcommuni...          RsvpEvent
# 41343  dear mom,\r\rhoping the other\r364 days of thi...       GreetingCard
# 40560  daniel & susan \rrequest the pleasure of your ...          RsvpEvent
# 19591  join us for brunch to celebrate the graduate\r...          RsvpEvent
# 25432  dear michelle,\r\rthank you so much for the th...       GreetingCard
# 36947  it's been too long!\rlets revive the lawson ha...          RsvpEvent
# 14564  nataly & richard \rbaby shower\r\rnos gustaría...          RsvpEvent
# 42691  lianne + paul\r\r\r\rare getting married\r\r\r...  DatedAnnouncement
# 9574   please join us in celebrating the\r\r\r\ropen ...          RsvpEvent
# 20705  colin, \rwow, you are officially an antique!  ...       GreetingCard
# 36572  hubs\r\rthank you for a wonderful mothers day\...       GreetingCard
# 5368                                                              RsvpEvent
# 5390   please come celebrate!\r beau & dean \rare tur...          RsvpEvent
# 37744  mom,\r\rtreat yourself to \rsomething sweet to...       GreetingCard
# 3636   friday\r\rto be announced ;)palmyra-macedon's\...          RsvpEvent
# 19259  biddy's 60th birthday\rplease join us for a bi...          RsvpEvent
# 31745  jump around!\r\r\rkarin's\rbirthday\r\r\r\r\r\...          RsvpEvent
# 34474  dear mom,\ri am blessed to have grown up in th...       GreetingCard
# 30927  mom,\rthank you for always being there. happy ...       GreetingCard
# 41826  thank you so much for coming to the wedding an...       GreetingCard
# 26178  join us for a birthday bbq\rwhen: saturday jul...       GreetingCard
# 17196  k.c. du fay invites you to a\rbirthday barbecu...          RsvpEvent
# 9673   nathalie's 1st birthday!\rwe did it! come cele...          RsvpEvent
# 16254  todd kraines & george glass\rinvite you to\r\r...          RsvpEvent
# 28151  date: tuesday, june 16th\rtime: 6:00-8:00pm\rl...          RsvpEvent
#
#          pred_primary_class  pred_primary_score  \
# 4003        wedding_related            0.813043
# 38188             greetings            0.945836
# 38913  birthday_celebration            0.967542
# 16224         organizations            0.667299
# 4693        wedding_related            0.869356
# 1958   birthday_celebration            0.996912
# 3541              greetings            0.990787
# 9657               personal            0.890758
# 3991   birthday_celebration            0.951438
# 40976       wedding_related            0.956258
# 11571  birthday_celebration            0.515358
# 20437  birthday_celebration            0.956336
# 40321       wedding_related            0.842825
# 3377               personal            0.798660
# 31097              personal            0.639156
# 7334        wedding_related            0.949025
# 37734              personal            0.970706
# 39875  birthday_celebration            0.930841
# 8838          organizations            0.834381
# 32256         organizations            0.507901
# 35160             greetings            0.925763
# 12148         organizations            0.843940
# 13197         organizations            0.660902
# 37338             greetings            0.971404
# 25224       wedding_related            0.930271
# 4288              greetings            0.982857
# 34323             greetings            0.986711
# 29000              personal            0.942248
# 21463         organizations            0.440534
# 45868  birthday_celebration            0.995362
# ...                     ...                 ...
# 16804       wedding_related            0.513396
# 42931              personal            0.840988
# 29567              personal            0.725282
# 1544               personal            0.767075
# 8033   birthday_celebration            0.971334
# 21950         organizations            0.897355
# 41343             greetings            0.956787
# 40560       wedding_related            0.854908
# 19591              personal            0.896191
# 25432             greetings            0.809109
# 36947              personal            0.566455
# 14564              personal            0.888522
# 42691       wedding_related            0.909381
# 9574          organizations            0.636697
# 20705             greetings            0.993089
# 36572             greetings            0.896444
# 5368               personal            0.664435
# 5390   birthday_celebration            0.964231
# 37744             greetings            0.963877
# 3636          organizations            0.897180
# 19259  birthday_celebration            0.965808
# 31745  birthday_celebration            0.990808
# 34474             greetings            0.973710
# 30927             greetings            0.943461
# 41826             greetings            0.882491
# 26178  birthday_celebration            0.921009
# 17196  birthday_celebration            0.894796
# 9673   birthday_celebration            0.983883
# 16254  birthday_celebration            0.953654
# 28151         organizations            0.825682
#
#                                     true_secondary_class  \
# 4003                               wedding_related_other
# 38188                             seasonal_holiday_cards
# 38913                                      kids_birthday
# 16224                             business_or_nonprofits
# 4693   parties_and_showers_in_honor_of_the_bride_&_groom
# 1958                                      adult_birthday
# 3541                                  everyday_greetings
# 9657                                other_holiday_events
# 3991                                       kids_birthday
# 40976  parties_and_showers_in_honor_of_the_bride_&_groom
# 11571                                 everyday_greetings
# 20437                                     adult_birthday
# 40321  parties_and_showers_in_honor_of_the_bride_&_groom
# 3377                              adult_or_family_events
# 31097                             business_or_nonprofits
# 7334      wedding_events_hosted_by_bride_groom_or_family
# 37734             celebrating_baby_kids_or_parents_to_be
# 39875                                      kids_birthday
# 8838                              adult_or_family_events
# 32256     wedding_events_hosted_by_bride_groom_or_family
# 35160                                 everyday_greetings
# 12148                           alumni_or_school_related
# 13197                             business_or_nonprofits
# 37338                                 everyday_greetings
# 25224  parties_and_showers_in_honor_of_the_bride_&_groom
# 4288                                  everyday_greetings
# 34323                                 everyday_greetings
# 29000                            seasonal_holiday_events
# 21463                             business_or_nonprofits
# 45868                                     adult_birthday
# ...                                                  ...
# 16804     wedding_events_hosted_by_bride_groom_or_family
# 42931                             adult_or_family_events
# 29567                               other_holiday_events
# 1544              celebrating_baby_kids_or_parents_to_be
# 8033                                       kids_birthday
# 21950                            seasonal_holiday_events
# 41343                                 everyday_greetings
# 40560     wedding_events_hosted_by_bride_groom_or_family
# 19591                             adult_or_family_events
# 25432                                 everyday_greetings
# 36947                                other_holiday_cards
# 14564             celebrating_baby_kids_or_parents_to_be
# 42691                                      save_the_date
# 9574                              business_or_nonprofits
# 20705                                 everyday_greetings
# 36572                                 everyday_greetings
# 5368                              adult_or_family_events
# 5390                                       kids_birthday
# 37744                                other_holiday_cards
# 3636                            alumni_or_school_related
# 19259                                     adult_birthday
# 31745                                     adult_birthday
# 34474                                other_holiday_cards
# 30927                                other_holiday_cards
# 41826                              wedding_related_other
# 26178                                      kids_birthday
# 17196                                     adult_birthday
# 9673                                       kids_birthday
# 16254                                      kids_birthday
# 28151                             business_or_nonprofits
#
#                                     pred_secondary_class  \
# 4003                               wedding_related_other
# 38188                             seasonal_holiday_cards
# 38913                                      kids_birthday
# 16224                             business_or_nonprofits
# 4693   parties_and_showers_in_honor_of_the_bride_&_groom
# 1958                                      adult_birthday
# 3541                                  everyday_greetings
# 9657                                other_holiday_events
# 3991                                       kids_birthday
# 40976  parties_and_showers_in_honor_of_the_bride_&_groom
# 11571                                 everyday_greetings
# 20437                                     adult_birthday
# 40321  parties_and_showers_in_honor_of_the_bride_&_groom
# 3377                              adult_or_family_events
# 31097                             adult_or_family_events
# 7334      wedding_events_hosted_by_bride_groom_or_family
# 37734             celebrating_baby_kids_or_parents_to_be
# 39875                                      kids_birthday
# 8838                              business_or_nonprofits
# 32256                             business_or_nonprofits
# 35160                                 everyday_greetings
# 12148                             business_or_nonprofits
# 13197                             business_or_nonprofits
# 37338                                 everyday_greetings
# 25224  parties_and_showers_in_honor_of_the_bride_&_groom
# 4288                                  everyday_greetings
# 34323                                 everyday_greetings
# 29000                            seasonal_holiday_events
# 21463                             business_or_nonprofits
# 45868                                     adult_birthday
# ...                                                  ...
# 16804  parties_and_showers_in_honor_of_the_bride_&_groom
# 42931                             adult_or_family_events
# 29567                             adult_or_family_events
# 1544              celebrating_baby_kids_or_parents_to_be
# 8033                                       kids_birthday
# 21950                             business_or_nonprofits
# 41343                                 everyday_greetings
# 40560     wedding_events_hosted_by_bride_groom_or_family
# 19591                             adult_or_family_events
# 25432                                 everyday_greetings
# 36947                             adult_or_family_events
# 14564             celebrating_baby_kids_or_parents_to_be
# 42691                                      save_the_date
# 9574                              business_or_nonprofits
# 20705                                 everyday_greetings
# 36572                                 everyday_greetings
# 5368                              adult_or_family_events
# 5390                                       kids_birthday
# 37744                                other_holiday_cards
# 3636                            alumni_or_school_related
# 19259                                            general
# 31745                                      kids_birthday
# 34474                                other_holiday_cards
# 30927                                other_holiday_cards
# 41826                                 everyday_greetings
# 26178                                      kids_birthday
# 17196                                     adult_birthday
# 9673                                       kids_birthday
# 16254                                      kids_birthday
# 28151                             business_or_nonprofits
#
#        pred_secondary_score                        true_tertiary_class  \
# 4003               0.853052                      other_wedding_related
# 38188              0.968027                                  christmas
# 38913              0.982516             little_kids_2_7_birthday_party
# 16224              0.821835  trunk_show_or_shopping_or_marketing_event
# 4693               0.702263                             wedding_shower
# 1958               0.857333                 other_adult_birthday_party
# 3541               0.970410                                   birthday
# 9657               0.907173                                  halloween
# 3991               0.995628                  tween_8_12_birthday_party
# 40976              0.988883                             wedding_shower
# 11571              0.933032                                   birthday
# 20437              0.808111                 other_adult_birthday_party
# 40321              0.987456                             wedding_shower
# 3377               0.831355                         farewell_or_moving
# 31097              0.379875           formal_reception_dinner_or_party
# 7334               0.949970                         wedding_invitation
# 37734              0.981363      baby_shower_or_new_baby_related_event
# 39875              0.750371             little_kids_2_7_birthday_party
# 8838               0.883404              general_party_food_and_drinks
# 32256              0.583802                         wedding_invitation
# 35160              0.825340                                    apology
# 12148              0.652492                     faculty_or_staff_event
# 13197              0.709675              meeting_lecture_or_networking
# 37338              0.979808                                  thank_you
# 25224              0.981902                           engagement_party
# 4288               0.935328                                  thank_you
# 34323              0.985818                                   birthday
# 29000              0.927813                                    holiday
# 21463              0.731393  trunk_show_or_shopping_or_marketing_event
# 45868              0.944536                 other_adult_birthday_party
# ...                     ...                                        ...
# 16804              0.585715                        night_before_drinks
# 42931              0.800047                               housewarming
# 29567              0.656237                               thanksgiving
# 1544               0.908694                         religious_ceremony
# 8033               0.993757             little_kids_2_7_birthday_party
# 21950              0.932762                                    holiday
# 41343              0.931566                                   birthday
# 40560              0.889782                         wedding_invitation
# 19591              0.831892                                 graduation
# 25432              0.976831                                  thank_you
# 36947              0.305212                                   hanukkah
# 14564              0.954347      baby_shower_or_new_baby_related_event
# 42691              0.978061                      wedding_save_the_date
# 9574               0.520142                            marketing_event
# 20705              0.978733                                  thank_you
# 36572              0.426422                                  thank_you
# 5368               0.726030              general_party_food_and_drinks
# 5390               0.987050             little_kids_2_7_birthday_party
# 37744              0.963607                                mothers_day
# 3636               0.970158                                    reunion
# 19259              0.578985             adult_milestone_birthday_party
# 31745              0.513210                 other_adult_birthday_party
# 34474              0.961652                                mothers_day
# 30927              0.926879                                mothers_day
# 41826              0.949814                          wedding_thank_you
# 26178              0.787839             little_kids_2_7_birthday_party
# 17196              0.545204                 other_adult_birthday_party
# 9673               0.972327                         1st_birthday_party
# 16254              0.875724                  other_kids_birthday_party
# 28151              0.592209                      casual_drinks_or_food
#
#               final_primary                                    final_secondary
# 4003        wedding_related                              wedding_related_other
# 38188             greetings                             seasonal_holiday_cards
# 38913  birthday_celebration                                      kids_birthday
# 16224         organizations                             business_or_nonprofits
# 4693        wedding_related  parties_and_showers_in_honor_of_the_bride_&_groom
# 1958   birthday_celebration                                     adult_birthday
# 3541              greetings                                 everyday_greetings
# 9657               personal                               other_holiday_events
# 3991   birthday_celebration                                      kids_birthday
# 40976       wedding_related  parties_and_showers_in_honor_of_the_bride_&_groom
# 11571           [greetings]                                 everyday_greetings
# 20437  birthday_celebration                                     adult_birthday
# 40321       wedding_related  parties_and_showers_in_honor_of_the_bride_&_groom
# 3377               personal                             adult_or_family_events
# 31097              personal                             adult_or_family_events
# 7334        wedding_related     wedding_events_hosted_by_bride_groom_or_family
# 37734              personal             celebrating_baby_kids_or_parents_to_be
# 39875  birthday_celebration                                      kids_birthday
# 8838          organizations                             business_or_nonprofits
# 32256         organizations                             business_or_nonprofits
# 35160             greetings                                 everyday_greetings
# 12148         organizations                             business_or_nonprofits
# 13197         organizations                             business_or_nonprofits
# 37338             greetings                                 everyday_greetings
# 25224       wedding_related  parties_and_showers_in_honor_of_the_bride_&_groom
# 4288              greetings                                 everyday_greetings
# 34323             greetings                                 everyday_greetings
# 29000              personal                            seasonal_holiday_events
# 21463         organizations                             business_or_nonprofits
# 45868  birthday_celebration                                     adult_birthday
# ...                     ...                                                ...
# 16804       wedding_related  parties_and_showers_in_honor_of_the_bride_&_groom
# 42931              personal                             adult_or_family_events
# 29567              personal                             adult_or_family_events
# 1544               personal             celebrating_baby_kids_or_parents_to_be
# 8033   birthday_celebration                                      kids_birthday
# 21950         organizations                             business_or_nonprofits
# 41343             greetings                                 everyday_greetings
# 40560       wedding_related     wedding_events_hosted_by_bride_groom_or_family
# 19591              personal                             adult_or_family_events
# 25432             greetings                                 everyday_greetings
# 36947              personal                             adult_or_family_events
# 14564              personal             celebrating_baby_kids_or_parents_to_be
# 42691       wedding_related                                      save_the_date
# 9574          organizations                             business_or_nonprofits
# 20705             greetings                                 everyday_greetings
# 36572             greetings                                 everyday_greetings
# 5368               personal                             adult_or_family_events
# 5390   birthday_celebration                                      kids_birthday
# 37744             greetings                                other_holiday_cards
# 3636          organizations                           alumni_or_school_related
# 19259  birthday_celebration                                            general
# 31745  birthday_celebration                                      kids_birthday
# 34474             greetings                                other_holiday_cards
# 30927             greetings                                other_holiday_cards
# 41826             greetings                                 everyday_greetings
# 26178  birthday_celebration                                      kids_birthday
# 17196  birthday_celebration                                     adult_birthday
# 9673   birthday_celebration                                      kids_birthday
# 16254  birthday_celebration                                      kids_birthday
# 28151         organizations                             business_or_nonprofits
#
# [7404 rows x 11 columns]
