# %%
import os
import time
from collections import Counter
import logging
import argparse

# helper modules
from ml_utils import pickle_classifier, load_classifier, ExtractFeature, \
                     precision_recall_matrix, get_classifier_results
from nlp_helper import CleanTextTransformer, tokenize_text
from query_events import execute_query

import pandas as pd
import numpy as np

from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer


from scipy.sparse import coo_matrix, hstack

# %%
logname = 'log/event_classifier_log'
logging.basicConfig(filename=logname,
                    filemode='a',
                    format='%(asctime)s -  %(name)s - %(levelname)s - %(message)s',
                    datefmt='%H:%M:%S',
                    level=logging.DEBUG)
logger = logging.getLogger(__name__)


parser = argparse.ArgumentParser(description='This is the event classifier program.')
parser.add_argument('--level', help='Level of classification, \
        usage: --level primary', choices=["primary", "secondary", "tertiary"], required=True)
parser.add_argument('--retrain', help='Retrain classifier. usage: --retrain F',
                    choices=['T', 'F'], required=True)
parser.add_argument('--load_clf', help='Load existing classifier. \
        usage: --load_clf classifiers/SVM_06202017121413.pkl', nargs='+', required=False)
parser.add_argument('--event_ids', help='Enter events to classify. If blank \
        then query will fetch all training data. usage: --event_ids 998746 \
        33384956 114992', nargs='+', required=False)
#filepath = os.path.dirname(__file__)
CLASSIFIER_DIR = os.path.join('/Users/iman/code/event_classifier/model/pickles/classifiers/')
FEATURE_DIR = os.path.join('/Users/iman/code/event_classifier/model/pickles/feature_pipelines/')

# Getting event text for classifier
QUERY_ALL = """

SELECT event_id
, p_class
, s_class
, t_class
, event_name as event_name
, event_type as event_type
, event_host as event_host
, event_subject as event_subject
, text_paper as event_text
, created
FROM (
    SELECT ce.event_id
    , CASE WHEN ce.p_class = 'skip' THEN 'other' ELSE ce.p_class END
    , CASE WHEN ce.s_class = 'skip' THEN 'other' ELSE ce.s_class END
    , CASE WHEN ce.t_class = 'skip' THEN 'other' ELSE ce.t_class END
    , e.name as event_name
    , e.type as event_type
    , e.host as event_host
    , e.subject as event_subject
    , listagg(TRIM(lower(cat.text))) as text_paper
    , ce.created_at as created
    FROM event_training_selections ce
    JOIN events e ON e.id = ce.event_id
    JOIN cards c ON c.event_id = ce.event_id
    JOIN card_sides cs ON cs.card_id = c.id
        AND cs.side_type_id = 0
    LEFT JOIN card_assets cat ON cat.card_side_id = cs.id
        AND cat.asset_type_id = 9
    WHERE ce.is_confirmed
    GROUP BY 1, 2, 3, 4, 5, 6, 7, 8, 10
    )
WHERE len(trim(event_name || ' ' || event_host || ' ' || event_subject ||
        ' ' || text_paper))
ORDER BY random()

"""

QUERY_EVENTS = """

SELECT event_id
, event_name as event_name
, event_type as event_type
, event_host as event_host
, event_subject as event_subject
, text_paper as event_text
, created
FROM (
    SELECT e.id as event_id
    , e.name as event_name
    , e.type as event_type
    , e.host as event_host
    , e.subject as event_subject
    , listagg(TRIM(lower(cat.text))) as text_paper
    , e.created_at as created
    FROM events e
    JOIN cards c ON c.event_id = e.id
    JOIN card_sides cs ON cs.card_id = c.id
        AND cs.side_type_id = 0
    LEFT JOIN card_assets cat ON cat.card_side_id = cs.id
        AND cat.asset_type_id = 9
    WHERE e.id LIKE {0}
    GROUP BY 1, 2, 3, 4, 5, 7
    )
WHERE len(trim(event_name || ' ' || event_host || ' ' || event_subject ||
        ' ' || text_paper))
ORDER BY random()

"""

# %%
def most_common(lst):
    """
    Using Counter find most common element in list
    Possible results:
        mc = [(val1,3)]
        mc = [(val1,2),(val2,1)]
        mc = [(val1,1),(val2,1),(val3,1)]
        ...
    No majority exists only when there is a tie, otherwise the first value of
    the list is the most common (because Counter sorts automatically in
    descending order by value)
    """

    # check if top two most common predictions are the same
    mc = Counter(lst).most_common(2)

    if len(mc) > 1 and mc[0][1] == mc[1][1]:
        return "no_majority"

    return mc[0][0]


def get_ensemble_prediction(results, classes):
    """
    if majority of classifiers choose same category, that's the winner.
    if majority does not exist, then select class with highest probability
    """

    print("Getting ensemble predictions...")
    num_clfs = len(results)

    # combine all classifier predictions and probabilities
    all_preds = np.array([v[0] for k, v in results.items()]).T
    all_probs = np.sum(np.array([v[1] for k, v in results.items()]), axis=0)
    all_probs_normalize = all_probs/num_clfs

    # the function most_common returns majority class or "no_majority"
    majority = np.array(list(map(most_common, all_preds)))
    no_majority_index = np.where(majority == 'no_majority')

    # for those where a majority doesn't exist, sum the probabilities for each
    # class
    no_majority_sum = all_probs_normalize[no_majority_index]

    # ensure no new probabilities were added that shouldn't be
    assert np.allclose(np.sum(no_majority_sum), len(no_majority_index[0])), (
           "probability sum is greater than expected for no_majority")

    # replace the "no_majority" samples with the class that resulted in the
    # largest probability
    majority[no_majority_index] = classes[np.argmax(no_majority_sum, axis=1)]

    return majority, np.max(all_probs_normalize, axis=1)

# %%
def load_classifier_list(clf):
    """
    Load a classifier
    Classifier is stored as list object
    Returns list of classifiers and their names
    """

    print("Loading classifier list...")
    # clean up input: remove "classifier/" and ".pkl"
    clf_id = clf[clf.find('/')+1:-4]

    clf_list, clf_names = [], []
    # this is a list of classifiers
    loaded_clf = load_classifier(CLASSIFIER_DIR + clf_id)
    for classifier in loaded_clf:
        clf_list.append(classifier)

        # get name via class structure
        clf_class = str(classifier.named_steps['clf'].__class__)

        # some basic cleaning of class name
        clf_name_indx = clf_class.find('.')
        clf_name = clf_class[clf_name_indx+1:-2]
        clf_names.append(clf_name)

    return clf_list, clf_names

# %%
def save_tertiary_features(feature_pipeline, level, id_num):
    """
    Save training features
    Need to create an id_num to know which classifier to load
    Loaded classifier must be the same as the feature id number
    """

    logger.info("Saving tertiary fitted feature pipeline id {}...".format(id_num))
    pickle_classifier(feature_pipeline, FEATURE_DIR + level + "_" + str(id_num))

    return id_num

# %%
def save_classifier(clf, level, id_num):
    """
    Save trained classifier
    """

    logger.info("Saving trained classifier id {}...".format(id_num))
    pickle_classifier(clf, CLASSIFIER_DIR + level + str(id_num))

# %%
# parameters for gridsearch
# using SVM currently
CLASSIFIER_PIPELINE = dict({
    'SVM': {
        'classifier': Pipeline([
            ("clf", SVC(probability=True)),
        ]),
        'params': {
            'clf__C': [1],
            'clf__kernel': ['linear']
        }
     },
})

# %%
def check_tertiary_dimensions(X, subject_matrix, text_matrix, event_type_matrix, predicted_primary_matrix, predicted_secondary_matrix):
    
    assert (X.shape[1] == subject_matrix.shape[1] + text_matrix.shape[1] + \
            event_type_matrix.shape[1] + predicted_primary_matrix.shape[1] + predicted_secondary_matrix.shape[1]), \
    ("Number of x_train features doesn't match sum of component features")
    
    assert (X.shape[0] == subject_matrix.shape[0]),\
    ("Number of x_train samples doesn't match subject_matrix samples")

    assert (X.shape[0] == text_matrix.shape[0]), \
    ("Number of x_train samples doesn't match body text samples")
    
    assert (X.shape[0] == event_type_matrix.shape[0]),\
    ("Number of x_train samples doesn't match event_type_matrix samples")

    assert (X.shape[0] == predicted_primary_matrix.shape[0]),\
    ("Number of x_train samples doesn't match event_type_matrix samples")

    assert (X.shape[0] == predicted_secondary_matrix.shape[0]),\
    ("Number of x_train samples doesn't match event_type_matrix samples")

# %%
def grid_search(X, y, gridsearch_pipeline):
    """
    Perform a Grid Search over the space of classifiers and their associated
    parameter space
    Inputs: X and y training sets
    Output: A list of the best classifiers from each classifier category
    """

    logger.info("starting Gridsearch...")

    best_classifiers = []
    names = []

    for v in gridsearch_pipeline.items():
        gs = GridSearchCV(v[1]['classifier'], v[1]['params'], verbose=2, cv=3, n_jobs=4)
        gs = gs.fit(X, y)
        names.append(v[0])
        logger.info("{} finished".format(v[0]))
        logger.info("Best scoring classifier: {}".format(gs.best_score_))
        best_classifiers.append(gs.best_estimator_)

    return best_classifiers, names

# %%
FEATURE_PIPELINE = dict({
    'subject_pipe':Pipeline([
                    ('cleanText', CleanTextTransformer()),
                    ('vectorizer', CountVectorizer(tokenizer=tokenize_text,ngram_range=(1, 1))),
                    ('tfidf', TfidfTransformer())
                    ]),
    'text_pipe': Pipeline([
                    ('cleanText', CleanTextTransformer()),
                    ('vectorizer', CountVectorizer(tokenizer=tokenize_text,ngram_range=(1, 1))),
                    ('tfidf', TfidfTransformer())
                    ]),
    'event_type_pipe': Pipeline([('vectorizer', CountVectorizer())]),
    'predicted_primary': Pipeline([('vectorizer', CountVectorizer())]),
    'predicted_secondary': Pipeline([('vectorizer', CountVectorizer())])
})

# %%
def get_tertiary_training_features(X, y, pipes):
    """
    Combines training features
    Using fit_transform on the pipeline object for each feature
    Performs sparse matrix concatenation
    """
    
    print("Beginning pipeline fit_transform to training data...")
    
    subject_matrix = pipes['subject_pipe'].fit_transform(X.subject, y)
    text_matrix = pipes['text_pipe'].fit_transform(X.text, y)
    event_type_matrix = pipes['event_type_pipe'].fit_transform(X.event_type, y)
    predicted_primary_matrix = pipes['predicted_primary'].fit_transform(X.final_primary, y)
    predicted_secondary_matrix = pipes['predicted_secondary'].fit_transform(X.final_secondary, y)
    
    X = hstack([subject_matrix, text_matrix, event_type_matrix, predicted_primary_matrix, predicted_secondary_matrix])
    
    print("Completed fit_transform")
    
    check_tertiary_dimensions(X, subject_matrix, text_matrix, event_type_matrix, predicted_primary_matrix, predicted_secondary_matrix)
    print("Training set dimension:", X.shape)
    
    return X, pipes

# %%
def get_tertiary_testing_features(X, pipes):
    """
    Combines training features
    Key difference between this and training_features
    is that pipeline is transforming x_test not fit_transforming
    """
    
    print("Beginning transform of test set...")
    subject_matrix = pipes['subject_pipe'].transform(X.subject)
    text_matrix = pipes['text_pipe'].transform(X.text)
    event_type_matrix = pipes['event_type_pipe'].transform(X.event_type)
    predicted_primary_matrix = pipes['predicted_primary'].transform(X.final_primary)
    predicted_secondary_matrix = pipes['predicted_secondary'].transform(X.final_secondary)
    
    X = hstack([subject_matrix, text_matrix, event_type_matrix, predicted_primary_matrix, predicted_secondary_matrix])
    
    print("Completed transform of test set.")
    
    check_tertiary_dimensions(X, subject_matrix, text_matrix, event_type_matrix, predicted_primary_matrix, predicted_secondary_matrix)
    print("Testing set dimension:", X.shape)
    
    return X

# %%
def _check_prediction_dimensions(y_test, y_pred, y_score):
    """
    Ensure that prediction dimensions are correct
    """

    assert y_pred.shape[0] == y_test.shape[0], (
        "Ensure class prediction vector is same length as test set")
    assert y_score.shape[0] == y_test.shape[0], (
        "Ensure score prediction vector is same length as test set")

# %%
import os
import time
from collections import Counter
import logging
import argparse

# helper modules
from ml_utils import pickle_classifier, load_classifier, ExtractFeature, \
                     precision_recall_matrix, get_classifier_results
from nlp_helper import CleanTextTransformer, tokenize_text
from query_events import execute_query

import pandas as pd
import numpy as np

from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer


from scipy.sparse import coo_matrix, hstack

# %%
# load dataset
df = pd.read_pickle('pickles/secondary_output/dataset_367.pkl')

# %%
df.final_primary.value_counts()
# Out:
# personal                630
# birthday_celebration    581
# greetings               520
# organizations           272
# wedding_related         215
# other                     4
# Name: final_primary, dtype: int64

# %%
y = df['true_tertiary_class']
X = df[['subject','text','event_type','final_primary','final_secondary','pred_primary_score','pred_secondary_score']]

# %%
id_num = 367

# %%
# split training, testing
x_train, x_test, y_train, y_test, idx1, idx2 = train_test_split(X, y, X.index, test_size=0.4)

# %%
x_train_matrix, feature_pipeline = get_tertiary_training_features(x_train, y_train, FEATURE_PIPELINE)
x_test_matrix = get_tertiary_testing_features(x_test, feature_pipeline)
# Out:
# Beginning pipeline fit_transform to training data...
# Completed fit_transform
# Training set dimension: (1333, 8731)
# Beginning transform of test set...
# Completed transform of test set.
# Testing set dimension: (889, 8731)

# %%
y_train.head()
# Out:
# 6370    little_kids_2_7_birthday_party
# 4315    adult_milestone_birthday_party
# 517                 reception_or_party
# 9402                 wedding_thank_you
# 6041                  engagement_party
# Name: true_tertiary_class, dtype: object

# %%
save_tertiary_features(feature_pipeline, 'tertiary', id_num)
# Out:
# Saving classifier: /Users/iman/code/event_classifier/model/pickles/feature_pipelines/tertiary_367...
# 367

# %%
clf_list, clf_names = grid_search(x_train_matrix, y_train, CLASSIFIER_PIPELINE)
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# /usr/local/lib/python3.6/site-packages/sklearn/model_selection/_split.py:581: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of groups for any class cannot be less than n_splits=3.
#   % (min_groups, self.n_splits)), Warning)
# [CV] clf__C=1, clf__kernel=linear ....................................
# [CV] clf__C=1, clf__kernel=linear ....................................
# [CV] clf__C=1, clf__kernel=linear ....................................
# [CV] ..................... clf__C=1, clf__kernel=linear, total=   2.6s
# [CV] ..................... clf__C=1, clf__kernel=linear, total=   3.0s
# [CV] ..................... clf__C=1, clf__kernel=linear, total=   3.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    3.4s finished

# %%
results, classes = get_classifier_results(clf_list, clf_names, x_test_matrix, y_test)
# Out:
# Getting classifier results...

# %%
#save_classifier(clf_list, 'tertiary', id_num)
# Out:
# Saving classifier: /Users/iman/code/event_classifier/model/pickles/classifiers/secondary_classifier_674...

# %%
y_pred, y_score = get_ensemble_prediction(results, classes)
_check_prediction_dimensions(y_test, y_pred, y_score)
# Out:
# Getting ensemble predictions...

# %%
def _decorate_with_tertiary(X, y_test, y_pred, y_score):
    """
    Adds two columns to x_test
        predicted primary class
        predicted primary score
    Used as input to secondary classifier
    """

    # uses output of primary model
    X['true_tertiary_class'] = y_test
    X['pred_tertiary_class'] = y_pred
    X['pred_tertiary_score'] = y_score

    return X

# %%
_decorate_with_tertiary(x_test, y_test, y_pred, y_score)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
#                                              subject  \
# 264     Hillman Scholars Holiday Break Dinner Invite
# 11770                  Steel & Lacquer Grand Opening
# 4204                     Carolyn Kim's Baby Sprinkle
# 1257              Andie's Tea for Two Birthday Party
# 9388           Beth & Devon Berry Moving Celebration
# 3204                 Elisha's Graduation Celebration
# 5937                                    Summer Party
# 12020           Annual Fund Kick-Off Dinner - Chairs
# 608                     Linnea's Graduation Luncheon
# 5648                            Dinner party invite
# 7558
# 11437                  Sarah and Stone's Baby Shower
# 2565                         Alicia Queen for a Day!
# 5183                          Tyler's First Birthday
# 10570            Jessica Favale Noonan's Baby Shower
# 1803                                Robby's Birthday
# 3199                           Alex's Birthday Party
# 3542                                  Happy Birthday
# 11440                      lisa and daniel mikelberg
# 7489                                       Thank You
# 5247                                  Italian Mochi
# 12999                      Sunday Brunch Celebration
# 10183  Alistair and Julie's 25th Wedding Anniversary
# 5778                                Super Bowl Party
# 3214                            Lalela Save the Date
# 7547                              Nath Holiday Party
# 11599                    Maggie Rich's 10th Birthday
# 1114                                 Happy Holidays!
# 4014                  Genessa's 33rd birthday dinner
# 6983                     Hannah's 5th Birthday Party
# ...                                              ...
# 3945                                       The Dunns
# 3950                       Kim Puttkammer's Birthday
# 13591                                       TBA Gala
# 8342                                 Happy Birthday!
# 7482            Retirement Luncheon for Steve Gipson
# 12747                          Anaya is turning ONE!
# 358            Melody Maids Mother Daughter Luncheon
# 1296                                 SHOWER FOR MARY
# 9253                  Garden Party Wedding Reception
# 1140                   Scarlett's 3rd Birthday Party
# 4294                 Madeline and Jonathan's Baptism
# 12563                  Madeline's 7th Birthday Party
# 4449                             Lauren's Bridal Tea
# 10697                                Ashley's Shower
# 10127     AGF, wine and live music fundraiser event.
# 10078                 Finn and Sylas' Birthday Prrty
# 7114                       Blessings, Books & Brunch
# 2878                         Juliette's 7th birthday
# 8956                                Marc's 40th bash
# 2997        iCrumz Prospective Investor Presentation
# 13506           Code of Support Foundation Reception
# 11590                               A Toast for Hana
# 2733                             Feliz cumpleañitos!
# 2894               An Enchanting Holiday Celebration
# 505                       Richard's Birthday Soirée
# 3221                            SEAN'S 10TH BIRTHDAY
# 761                E & Addison's Football Open House
# 5552                             Jen's 30th Birthday
# 12037                Christina Marie's Bridal Shower
# 10525                                   Summer party
#
#                                                     text         event_type  \
# 264    jennifer & tom hillman\r invite you\rto an eve...          RsvpEvent
# 11770                                                             RsvpEvent
# 4204   please join us\rfor a baby sprinkle\rin honor ...          RsvpEvent
# 1257   tea for two\randie is turning two \r&\rwe’re h...          RsvpEvent
# 9388   save the date\rfor an intimate gathering  \r  ...          RsvpEvent
# 3204   mr. and mrs. john tran\rinvite you to join the...          RsvpEvent
# 5937   summer party!\rlet's get together for no speci...          RsvpEvent
# 12020  please join us\ron\rwednesday, november 11th\r...          RsvpEvent
# 608    this fall, linnea will be attending smith coll...          RsvpEvent
# 5648   john & shara\rinvite you to\r\rcocktails & din...          RsvpEvent
# 7558                          upload \ryour\rown\rdesign          RsvpEvent
# 11437  "it is the most powerful creation to have life...          RsvpEvent
# 2565   please join us in toasting\ralicia kennaugh's\...          RsvpEvent
# 5183   please join us to celebrate\rtyler's\rfirst bi...          RsvpEvent
# 10570  jessica is having a baby\rjoin us to shower he...          RsvpEvent
# 1803   please\rjoin us\rfor\r\r\r\r\r\r\ra\rbirthday\...          RsvpEvent
# 3199   come\rcelebrate\r\ralex is turning twelve (!)\...          RsvpEvent
# 3542   dear ellen,\r \rsending love and best wishes\r...       GreetingCard
# 11440  lisa and daniel are getting married\rplease jo...          RsvpEvent
# 7489   angel, jody, tatiana, connor\rthank you so muc...       GreetingCard
# 5247   italian mochi,\renjoy your weekend with your f...       GreetingCard
# 12999  you’re invited to sunday brunch with \rchaunce...          RsvpEvent
# 10183  celebrating \r25 happy years together\rplease ...          RsvpEvent
# 5778   come on over for\rchili, apps\rand\rthe superb...          RsvpEvent
# 3214   come party with \rlalela\rin a celebration of ...  DatedAnnouncement
# 7547   please join us for a holiday party\rwith frien...          RsvpEvent
# 11599  you're invited to \rmaggie's\rbirthday!\rjoin ...          RsvpEvent
# 1114   may you find\rhealth, happiness\rand peace\rdu...       GreetingCard
# 4014   please join us for\rdrinks and dinner\rto cele...          RsvpEvent
# 6983   please join us for\rhannah's 5th birthday!\r\r...          RsvpEvent
# ...                                                  ...                ...
# 3945   uncle mike, aunt melissa and lucas (and bump):...       GreetingCard
# 3950   come\rcelebrate \r--  kim's birthday -- \rappe...          RsvpEvent
# 13591  $100 per person\ror choose \ra donation level,...          RsvpEvent
# 8342   aunt bev,\r\rsending you \rlove & best wishes ...       GreetingCard
# 7482   please join us as we celebrate\rthe retirement...          RsvpEvent
# 12747                                                             RsvpEvent
# 358    melody maids\r\rmother daughter luncheon\rsund...          RsvpEvent
# 1296   join us for a baby shower\rin honor of mary\r\...          RsvpEvent
# 9253   sid & sophie\r\rinvite you and your family to ...          RsvpEvent
# 1140                                                              RsvpEvent
# 4294   joseph and julie invite you to\rthe christenin...          RsvpEvent
# 12563  all aboard the art truck! \rto celebrate \rmad...          RsvpEvent
# 4449   shirley 'zen' campbell\rrequests the pleasure ...          RsvpEvent
# 10697  let's celebrate\rashley\rour\rbride-to-be\r\rs...          RsvpEvent
# 10127  a global friendship.\r\rwomen to women fundrai...          RsvpEvent
# 10078  finn and sylas walden are turning 5 and 6! \rp...          RsvpEvent
# 7114   please join us for the aufruf of sarah & billy...          RsvpEvent
# 2878   juliette's 7th birthday lunch\r\r\rplease join...          RsvpEvent
# 8956   saturday, june 6th, 2015 4 o’clock\r\rmarc tur...          RsvpEvent
# 2997   icrumz\rprospective investor presentation\r\ry...          RsvpEvent
# 13506  hi! i'm ey's federal health sector lead, and a...          RsvpEvent
# 11590  join marc and susan\ras we toast our daughter\...          RsvpEvent
# 2733   happy\rbirthdayqueridísima pao,\rhoy celebro t...       GreetingCard
# 2894   you're invited to...\ran enchanting \rholiday ...          RsvpEvent
# 505    an evening of\r"more champagne"!!!\r\rmarch 7t...          RsvpEvent
# 3221   sean cowie’s\r10th birthday\r\rthursday, june ...          RsvpEvent
# 761    nfl championship sunday\ropen house\rwith beer...          RsvpEvent
# 5552   come celebrate \rjen's 30th birthday\rsaturday...          RsvpEvent
# 12037  we request the pleasure of your company\r for ...          RsvpEvent
# 10525  jan & jerry\rinvite you to a\rmid-summer party...          RsvpEvent
#
#               final_primary  \
# 264                personal
# 11770         organizations
# 4204               personal
# 1257   birthday_celebration
# 9388          organizations
# 3204               personal
# 5937               personal
# 12020         organizations
# 608                personal
# 5648               personal
# 7558          organizations
# 11437              personal
# 2565   birthday_celebration
# 5183   birthday_celebration
# 10570              personal
# 1803   birthday_celebration
# 3199   birthday_celebration
# 3542              greetings
# 11440       wedding_related
# 7489              greetings
# 5247              greetings
# 12999              personal
# 10183       wedding_related
# 5778               personal
# 3214        wedding_related
# 7547               personal
# 11599  birthday_celebration
# 1114              greetings
# 4014   birthday_celebration
# 6983   birthday_celebration
# ...                     ...
# 3945              greetings
# 3950   birthday_celebration
# 13591         organizations
# 8342              greetings
# 7482               personal
# 12747  birthday_celebration
# 358           organizations
# 1296               personal
# 9253        wedding_related
# 1140   birthday_celebration
# 4294               personal
# 12563  birthday_celebration
# 4449        wedding_related
# 10697              personal
# 10127         organizations
# 10078  birthday_celebration
# 7114               personal
# 2878   birthday_celebration
# 8956   birthday_celebration
# 2997          organizations
# 13506         organizations
# 11590              personal
# 2733              greetings
# 2894               personal
# 505    birthday_celebration
# 3221   birthday_celebration
# 761                personal
# 5552   birthday_celebration
# 12037       wedding_related
# 10525              personal
#
#                                          final_secondary  pred_primary_score  \
# 264                              seasonal_holiday_events            0.526091
# 11770                             business_or_nonprofits            0.720366
# 4204              celebrating_baby_kids_or_parents_to_be            0.875800
# 1257                                       kids_birthday            0.942905
# 9388                              business_or_nonprofits            0.333730
# 3204                              adult_or_family_events            0.898763
# 5937                              adult_or_family_events            0.619851
# 12020                             business_or_nonprofits            0.744873
# 608                               adult_or_family_events            0.711789
# 5648                              adult_or_family_events            0.616328
# 7558                              business_or_nonprofits            0.526219
# 11437             celebrating_baby_kids_or_parents_to_be            0.908270
# 2565                                      adult_birthday            0.498591
# 5183                                       kids_birthday            0.957387
# 10570             celebrating_baby_kids_or_parents_to_be            0.943177
# 1803                                      adult_birthday            0.986891
# 3199                                       kids_birthday            0.954261
# 3542                                  everyday_greetings            0.985201
# 11440  parties_and_showers_in_honor_of_the_bride_&_groom            0.518074
# 7489                                  everyday_greetings            0.865892
# 5247                                  everyday_greetings            0.735244
# 12999                             adult_or_family_events            0.613804
# 10183     wedding_events_hosted_by_bride_groom_or_family            0.526940
# 5778                              adult_or_family_events            0.735064
# 3214                                       save_the_date            0.561539
# 7547                             seasonal_holiday_events            0.819344
# 11599                                      kids_birthday            0.938434
# 1114                              seasonal_holiday_cards            0.964695
# 4014                                      adult_birthday            0.934949
# 6983                                       kids_birthday            0.955138
# ...                                                  ...                 ...
# 3945                                  everyday_greetings            0.898553
# 3950                                      adult_birthday            0.929184
# 13591                             business_or_nonprofits            0.415555
# 8342                                  everyday_greetings            0.988318
# 7482                              adult_or_family_events            0.644139
# 12747                                      kids_birthday            0.903863
# 358                               business_or_nonprofits            0.440311
# 1296              celebrating_baby_kids_or_parents_to_be            0.867950
# 9253      wedding_events_hosted_by_bride_groom_or_family            0.771767
# 1140                                       kids_birthday            0.866939
# 4294              celebrating_baby_kids_or_parents_to_be            0.811371
# 12563                                      kids_birthday            0.934513
# 4449   parties_and_showers_in_honor_of_the_bride_&_groom            0.827976
# 10697             celebrating_baby_kids_or_parents_to_be            0.573516
# 10127                             business_or_nonprofits            0.792507
# 10078                                      kids_birthday            0.960517
# 7114                              adult_or_family_events            0.560008
# 2878                                       kids_birthday            0.923649
# 8956                                      adult_birthday            0.774363
# 2997                              business_or_nonprofits            0.693065
# 13506                             business_or_nonprofits            0.788568
# 11590                             adult_or_family_events            0.591388
# 2733                                  everyday_greetings            0.498143
# 2894                             seasonal_holiday_events            0.559917
# 505                                        kids_birthday            0.847375
# 3221                                       kids_birthday            0.928043
# 761                               adult_or_family_events            0.720277
# 5552                                      adult_birthday            0.976029
# 12037  parties_and_showers_in_honor_of_the_bride_&_groom            0.867332
# 10525                             adult_or_family_events            0.695565
#
#        pred_secondary_score                    true_tertiary_class  \
# 264                0.266389          general_party_food_and_drinks
# 11770              0.712480                grand_opening_or_launch
# 4204               0.711040  baby_shower_or_new_baby_related_event
# 1257               0.710637         little_kids_2_7_birthday_party
# 9388               0.687706                     farewell_or_moving
# 3204               0.708765                             graduation
# 5937               0.790516          general_party_food_and_drinks
# 12020              0.688900            fundraiser_or_charity_event
# 608                0.730994                             graduation
# 5648               0.600318          general_party_food_and_drinks
# 7558               0.726377                                  other
# 11437              0.804286  baby_shower_or_new_baby_related_event
# 2565               0.548823         adult_milestone_birthday_party
# 5183               0.548460                     1st_birthday_party
# 10570              0.832302  baby_shower_or_new_baby_related_event
# 1803               0.563896             other_adult_birthday_party
# 3199               0.730624              tween_8_12_birthday_party
# 3542               0.909527                               birthday
# 11440              0.624162                       engagement_party
# 7489               0.891407                      wedding_thank_you
# 5247               0.659490                              thank_you
# 12999              0.447872          general_party_food_and_drinks
# 10183              0.500764                            anniversary
# 5778               0.753232                sports_or_viewing_party
# 3214               0.574162                     reception_or_party
# 7547               0.666747                                holiday
# 11599              0.799814              tween_8_12_birthday_party
# 1114               0.758290                                holiday
# 4014               0.791049             other_adult_birthday_party
# 6983               0.840975         little_kids_2_7_birthday_party
# ...                     ...                                    ...
# 3945               0.734118                              thank_you
# 3950               0.539322             other_adult_birthday_party
# 13591              0.655278                        gala_or_benefit
# 8342               0.908165                               birthday
# 7482               0.596899                             retirement
# 12747              0.664669                     1st_birthday_party
# 358                0.534964                     reception_or_party
# 1296               0.721368  baby_shower_or_new_baby_related_event
# 9253               0.702266                    other_wedding_event
# 1140               0.807462         little_kids_2_7_birthday_party
# 4294               0.551382                     religious_ceremony
# 12563              0.827813         little_kids_2_7_birthday_party
# 4449               0.753696                         wedding_shower
# 10697              0.429316              bachelorette_or_hen_party
# 10127              0.662190            fundraiser_or_charity_event
# 10078              0.653849         little_kids_2_7_birthday_party
# 7114               0.533366                    other_general_party
# 2878               0.770186         little_kids_2_7_birthday_party
# 8956               0.566763         adult_milestone_birthday_party
# 2997               0.665360                  meeting_or_conference
# 13506              0.685255                     reception_or_party
# 11590              0.473207                    other_general_party
# 2733               0.463558                       foreign_language
# 2894               0.499703                                holiday
# 505                0.554284             other_adult_birthday_party
# 3221               0.772048              tween_8_12_birthday_party
# 761                0.579374                sports_or_viewing_party
# 5552               0.798500         adult_milestone_birthday_party
# 12037              0.827270                         wedding_shower
# 10525              0.736966                    other_general_party
#
#                              pred_tertiary_class  pred_tertiary_score
# 264                                holiday_party             0.202715
# 11770                         reception_or_party             0.189758
# 4204       baby_shower_or_new_baby_related_event             0.587541
# 1257              little_kids_2_7_birthday_party             0.627751
# 9388                          reception_or_party             0.295725
# 3204                                  graduation             0.089326
# 5937               general_party_food_and_drinks             0.324084
# 12020                         reception_or_party             0.368597
# 608                                   graduation             0.130704
# 5648               general_party_food_and_drinks             0.302011
# 7558                          reception_or_party             0.121404
# 11437      baby_shower_or_new_baby_related_event             0.601992
# 2565              adult_milestone_birthday_party             0.500189
# 5183              little_kids_2_7_birthday_party             0.328011
# 10570      baby_shower_or_new_baby_related_event             0.603310
# 1803                  other_adult_birthday_party             0.278352
# 3199                  other_adult_birthday_party             0.397650
# 3542                                    birthday             0.735535
# 11440                           engagement_party             0.229232
# 7489                                   thank_you             0.438612
# 5247                                   thank_you             0.153879
# 12999              general_party_food_and_drinks             0.312180
# 10183                         wedding_invitation             0.292189
# 5778               general_party_food_and_drinks             0.159656
# 3214                       wedding_save_the_date             0.150113
# 7547                                     holiday             0.378176
# 11599                  tween_8_12_birthday_party             0.356405
# 1114                                     holiday             0.488756
# 4014                  other_adult_birthday_party             0.338601
# 6983              little_kids_2_7_birthday_party             0.772013
# ...                                          ...                  ...
# 3945                                   thank_you             0.365268
# 3950                  other_adult_birthday_party             0.386933
# 13591                         reception_or_party             0.262039
# 8342                                    birthday             0.756510
# 7482               general_party_food_and_drinks             0.204293
# 12747             little_kids_2_7_birthday_party             0.395982
# 358         other_alumni_or_school_related_event             0.202018
# 1296       baby_shower_or_new_baby_related_event             0.499260
# 9253                          wedding_invitation             0.378978
# 1140              little_kids_2_7_birthday_party             0.676484
# 4294                          religious_ceremony             0.203141
# 12563             little_kids_2_7_birthday_party             0.721271
# 4449                              wedding_shower             0.472363
# 10697      baby_shower_or_new_baby_related_event             0.434839
# 10127  trunk_show_or_shopping_or_marketing_event             0.245628
# 10078             little_kids_2_7_birthday_party             0.258192
# 7114               general_party_food_and_drinks             0.249714
# 2878              little_kids_2_7_birthday_party             0.717019
# 8956              adult_milestone_birthday_party             0.714318
# 2997                          reception_or_party             0.259455
# 13506                         reception_or_party             0.386723
# 11590                         farewell_or_moving             0.157655
# 2733                                    birthday             0.136755
# 2894                                     holiday             0.381973
# 505               little_kids_2_7_birthday_party             0.298333
# 3221                   tween_8_12_birthday_party             0.422784
# 761                general_party_food_and_drinks             0.160441
# 5552              adult_milestone_birthday_party             0.681600
# 12037                             wedding_shower             0.426923
# 10525              general_party_food_and_drinks             0.326069
#
# [889 rows x 10 columns]

# %%
hierarchy = pd.DataFrame.from_csv('pickles/hierarchy.csv')

# %%
hierarchy.head()
# Out:
#                 p_class                 s_class                     t_class
# 0  birthday_celebration           kids_birthday   tween_8_12_birthday_party
# 1  birthday_celebration          adult_birthday  other_adult_birthday_party
# 2         organizations  business_or_nonprofits          reception_or_party
# 3              personal  adult_or_family_events                  retirement
# 4              personal  adult_or_family_events         other_general_party

# %%
x_test.head(50)
# Out:
#                                              subject  \
# 264     Hillman Scholars Holiday Break Dinner Invite
# 11770                  Steel & Lacquer Grand Opening
# 4204                     Carolyn Kim's Baby Sprinkle
# 1257              Andie's Tea for Two Birthday Party
# 9388           Beth & Devon Berry Moving Celebration
# 3204                 Elisha's Graduation Celebration
# 5937                                    Summer Party
# 12020           Annual Fund Kick-Off Dinner - Chairs
# 608                     Linnea's Graduation Luncheon
# 5648                            Dinner party invite
# 7558
# 11437                  Sarah and Stone's Baby Shower
# 2565                         Alicia Queen for a Day!
# 5183                          Tyler's First Birthday
# 10570            Jessica Favale Noonan's Baby Shower
# 1803                                Robby's Birthday
# 3199                           Alex's Birthday Party
# 3542                                  Happy Birthday
# 11440                      lisa and daniel mikelberg
# 7489                                       Thank You
# 5247                                  Italian Mochi
# 12999                      Sunday Brunch Celebration
# 10183  Alistair and Julie's 25th Wedding Anniversary
# 5778                                Super Bowl Party
# 3214                            Lalela Save the Date
# 7547                              Nath Holiday Party
# 11599                    Maggie Rich's 10th Birthday
# 1114                                 Happy Holidays!
# 4014                  Genessa's 33rd birthday dinner
# 6983                     Hannah's 5th Birthday Party
# 2008                    Connor Vert's First Birthday
# 5458                             Field to Feast 2015
# 12858             Ariella and Natanya's Bnot Mitzvah
# 13475                                      Thank you
# 6192                      Thanks and happy holidays!
# 3201                   Wedding Shower for Jina & Rob
# 605    Maya and Noam's Bnei Mitzvah Celebration  ...
# 6939                       Happy New Year, Professor
# 1718                          Happy Valentine's Day!
# 3999                      Bob's Birthday Dinner 2015
# 9517                  Tyler Teske's Graduation Party
# 5573                                  Happy Holidays
# 6642                          Alyssa's Bridal Shower
# 11468                                 Proud of You!!
# 9596                           My Thirtieth Birthday
# 3058                Connor Thompson's Birthday Party
# 51           A Surprise Baby Shower for Asha Kaufman
# 2906                           KELLEN'S 4TH BIRTHDAY
# 3596                  Nicky and Travis's Baby Shower
# 1545                         Robert's 45th Birthday!
#
#                                                     text         event_type  \
# 264    jennifer & tom hillman\r invite you\rto an eve...          RsvpEvent
# 11770                                                             RsvpEvent
# 4204   please join us\rfor a baby sprinkle\rin honor ...          RsvpEvent
# 1257   tea for two\randie is turning two \r&\rwe’re h...          RsvpEvent
# 9388   save the date\rfor an intimate gathering  \r  ...          RsvpEvent
# 3204   mr. and mrs. john tran\rinvite you to join the...          RsvpEvent
# 5937   summer party!\rlet's get together for no speci...          RsvpEvent
# 12020  please join us\ron\rwednesday, november 11th\r...          RsvpEvent
# 608    this fall, linnea will be attending smith coll...          RsvpEvent
# 5648   john & shara\rinvite you to\r\rcocktails & din...          RsvpEvent
# 7558                          upload \ryour\rown\rdesign          RsvpEvent
# 11437  "it is the most powerful creation to have life...          RsvpEvent
# 2565   please join us in toasting\ralicia kennaugh's\...          RsvpEvent
# 5183   please join us to celebrate\rtyler's\rfirst bi...          RsvpEvent
# 10570  jessica is having a baby\rjoin us to shower he...          RsvpEvent
# 1803   please\rjoin us\rfor\r\r\r\r\r\r\ra\rbirthday\...          RsvpEvent
# 3199   come\rcelebrate\r\ralex is turning twelve (!)\...          RsvpEvent
# 3542   dear ellen,\r \rsending love and best wishes\r...       GreetingCard
# 11440  lisa and daniel are getting married\rplease jo...          RsvpEvent
# 7489   angel, jody, tatiana, connor\rthank you so muc...       GreetingCard
# 5247   italian mochi,\renjoy your weekend with your f...       GreetingCard
# 12999  you’re invited to sunday brunch with \rchaunce...          RsvpEvent
# 10183  celebrating \r25 happy years together\rplease ...          RsvpEvent
# 5778   come on over for\rchili, apps\rand\rthe superb...          RsvpEvent
# 3214   come party with \rlalela\rin a celebration of ...  DatedAnnouncement
# 7547   please join us for a holiday party\rwith frien...          RsvpEvent
# 11599  you're invited to \rmaggie's\rbirthday!\rjoin ...          RsvpEvent
# 1114   may you find\rhealth, happiness\rand peace\rdu...       GreetingCard
# 4014   please join us for\rdrinks and dinner\rto cele...          RsvpEvent
# 6983   please join us for\rhannah's 5th birthday!\r\r...          RsvpEvent
# 2008   calling all critters for\r\rconnor's first bir...          RsvpEvent
# 5458   field to feast 2015\r\r\r\r\rseptember 5th\rat...          RsvpEvent
# 12858  please join us as we celebrate the bnot mitzva...          RsvpEvent
# 13475  thank you\rthank you for joining us on this jo...       GreetingCard
# 6192   here's to health, wealth, happiness, and love\...       GreetingCard
# 3201   husband and wife they will become, \rso let's ...          RsvpEvent
# 605    join us to celebrate the bnei mitzvah of\r\rno...          RsvpEvent
# 6939   may every day of the new year \rglow with good...       GreetingCard
# 1718   happy valentine's day to my favourite nieces! ...       GreetingCard
# 3999   let's celebrate bob's birthday!\r(a little ear...          RsvpEvent
# 9517   please join us in celebrating\rtyler teske's g...          RsvpEvent
# 5573   may your holidays be filled with \rpeace and c...       GreetingCard
# 6642   please join us for a \rbridal shower in honor ...          RsvpEvent
# 11468  boog...\r\rwe all think you're wonderful!!\rwe...       GreetingCard
# 9596   please celebrate\rmy thirtieth birthday\rwith ...          RsvpEvent
# 3058   connor thompson\ris turning 5\r\rsaturday, jan...          RsvpEvent
# 51     join us for\ra surprise baby shower\rin honor ...          RsvpEvent
# 2906   kellen's \rturning four!\r\rsaturday, november...          RsvpEvent
# 3596   incoming ski bunny!\rnicky & travis's little b...          RsvpEvent
# 1545   raise a glass to help robert forget - umm, cel...          RsvpEvent
#
#               final_primary  \
# 264                personal
# 11770         organizations
# 4204               personal
# 1257   birthday_celebration
# 9388          organizations
# 3204               personal
# 5937               personal
# 12020         organizations
# 608                personal
# 5648               personal
# 7558          organizations
# 11437              personal
# 2565   birthday_celebration
# 5183   birthday_celebration
# 10570              personal
# 1803   birthday_celebration
# 3199   birthday_celebration
# 3542              greetings
# 11440       wedding_related
# 7489              greetings
# 5247              greetings
# 12999              personal
# 10183       wedding_related
# 5778               personal
# 3214        wedding_related
# 7547               personal
# 11599  birthday_celebration
# 1114              greetings
# 4014   birthday_celebration
# 6983   birthday_celebration
# 2008   birthday_celebration
# 5458               personal
# 12858              personal
# 13475             greetings
# 6192              greetings
# 3201        wedding_related
# 605                personal
# 6939              greetings
# 1718              greetings
# 3999   birthday_celebration
# 9517               personal
# 5573              greetings
# 6642        wedding_related
# 11468             greetings
# 9596   birthday_celebration
# 3058   birthday_celebration
# 51                 personal
# 2906   birthday_celebration
# 3596               personal
# 1545   birthday_celebration
#
#                                          final_secondary  pred_primary_score  \
# 264                              seasonal_holiday_events            0.526091
# 11770                             business_or_nonprofits            0.720366
# 4204              celebrating_baby_kids_or_parents_to_be            0.875800
# 1257                                       kids_birthday            0.942905
# 9388                              business_or_nonprofits            0.333730
# 3204                              adult_or_family_events            0.898763
# 5937                              adult_or_family_events            0.619851
# 12020                             business_or_nonprofits            0.744873
# 608                               adult_or_family_events            0.711789
# 5648                              adult_or_family_events            0.616328
# 7558                              business_or_nonprofits            0.526219
# 11437             celebrating_baby_kids_or_parents_to_be            0.908270
# 2565                                      adult_birthday            0.498591
# 5183                                       kids_birthday            0.957387
# 10570             celebrating_baby_kids_or_parents_to_be            0.943177
# 1803                                      adult_birthday            0.986891
# 3199                                       kids_birthday            0.954261
# 3542                                  everyday_greetings            0.985201
# 11440  parties_and_showers_in_honor_of_the_bride_&_groom            0.518074
# 7489                                  everyday_greetings            0.865892
# 5247                                  everyday_greetings            0.735244
# 12999                             adult_or_family_events            0.613804
# 10183     wedding_events_hosted_by_bride_groom_or_family            0.526940
# 5778                              adult_or_family_events            0.735064
# 3214                                       save_the_date            0.561539
# 7547                             seasonal_holiday_events            0.819344
# 11599                                      kids_birthday            0.938434
# 1114                              seasonal_holiday_cards            0.964695
# 4014                                      adult_birthday            0.934949
# 6983                                       kids_birthday            0.955138
# 2008                                       kids_birthday            0.919426
# 5458                              adult_or_family_events            0.623657
# 12858             celebrating_baby_kids_or_parents_to_be            0.731917
# 13475                                 everyday_greetings            0.926583
# 6192                                  everyday_greetings            0.976133
# 3201   parties_and_showers_in_honor_of_the_bride_&_groom            0.880536
# 605               celebrating_baby_kids_or_parents_to_be            0.651383
# 6939                              seasonal_holiday_cards            0.878634
# 1718                                 other_holiday_cards            0.936466
# 3999                                      adult_birthday            0.986665
# 9517                              adult_or_family_events            0.879535
# 5573                              seasonal_holiday_cards            0.937941
# 6642   parties_and_showers_in_honor_of_the_bride_&_groom            0.869615
# 11468                                 everyday_greetings            0.869132
# 9596                                      adult_birthday            0.957826
# 3058                                       kids_birthday            0.947136
# 51                celebrating_baby_kids_or_parents_to_be            0.872281
# 2906                                       kids_birthday            0.961193
# 3596              celebrating_baby_kids_or_parents_to_be            0.888229
# 1545                                      adult_birthday            0.888510
#
#        pred_secondary_score                    true_tertiary_class  \
# 264                0.266389          general_party_food_and_drinks
# 11770              0.712480                grand_opening_or_launch
# 4204               0.711040  baby_shower_or_new_baby_related_event
# 1257               0.710637         little_kids_2_7_birthday_party
# 9388               0.687706                     farewell_or_moving
# 3204               0.708765                             graduation
# 5937               0.790516          general_party_food_and_drinks
# 12020              0.688900            fundraiser_or_charity_event
# 608                0.730994                             graduation
# 5648               0.600318          general_party_food_and_drinks
# 7558               0.726377                                  other
# 11437              0.804286  baby_shower_or_new_baby_related_event
# 2565               0.548823         adult_milestone_birthday_party
# 5183               0.548460                     1st_birthday_party
# 10570              0.832302  baby_shower_or_new_baby_related_event
# 1803               0.563896             other_adult_birthday_party
# 3199               0.730624              tween_8_12_birthday_party
# 3542               0.909527                               birthday
# 11440              0.624162                       engagement_party
# 7489               0.891407                      wedding_thank_you
# 5247               0.659490                              thank_you
# 12999              0.447872          general_party_food_and_drinks
# 10183              0.500764                            anniversary
# 5778               0.753232                sports_or_viewing_party
# 3214               0.574162                     reception_or_party
# 7547               0.666747                                holiday
# 11599              0.799814              tween_8_12_birthday_party
# 1114               0.758290                                holiday
# 4014               0.791049             other_adult_birthday_party
# 6983               0.840975         little_kids_2_7_birthday_party
# 2008               0.527107                     1st_birthday_party
# 5458               0.393965          general_party_food_and_drinks
# 12858              0.658371                     bar_or_bat_mitzvah
# 13475              0.892683                              thank_you
# 6192               0.554246                                holiday
# 3201               0.546297                         wedding_shower
# 605                0.531570                     bar_or_bat_mitzvah
# 6939               0.726663                              new_years
# 1718               0.803666                             valentines
# 3999               0.768460                 general_birthday_party
# 9517               0.780857                             graduation
# 5573               0.756802                                holiday
# 6642               0.874793                         wedding_shower
# 11468              0.694073                   love_or_just_because
# 9596               0.623084         adult_milestone_birthday_party
# 3058               0.778585         little_kids_2_7_birthday_party
# 51                 0.841581  baby_shower_or_new_baby_related_event
# 2906               0.865437         little_kids_2_7_birthday_party
# 3596               0.877962  baby_shower_or_new_baby_related_event
# 1545               0.546436         adult_milestone_birthday_party
#
#                          pred_tertiary_class  pred_tertiary_score
# 264                            holiday_party             0.202715
# 11770                     reception_or_party             0.189758
# 4204   baby_shower_or_new_baby_related_event             0.587541
# 1257          little_kids_2_7_birthday_party             0.627751
# 9388                      reception_or_party             0.295725
# 3204                              graduation             0.089326
# 5937           general_party_food_and_drinks             0.324084
# 12020                     reception_or_party             0.368597
# 608                               graduation             0.130704
# 5648           general_party_food_and_drinks             0.302011
# 7558                      reception_or_party             0.121404
# 11437  baby_shower_or_new_baby_related_event             0.601992
# 2565          adult_milestone_birthday_party             0.500189
# 5183          little_kids_2_7_birthday_party             0.328011
# 10570  baby_shower_or_new_baby_related_event             0.603310
# 1803              other_adult_birthday_party             0.278352
# 3199              other_adult_birthday_party             0.397650
# 3542                                birthday             0.735535
# 11440                       engagement_party             0.229232
# 7489                               thank_you             0.438612
# 5247                               thank_you             0.153879
# 12999          general_party_food_and_drinks             0.312180
# 10183                     wedding_invitation             0.292189
# 5778           general_party_food_and_drinks             0.159656
# 3214                   wedding_save_the_date             0.150113
# 7547                                 holiday             0.378176
# 11599              tween_8_12_birthday_party             0.356405
# 1114                                 holiday             0.488756
# 4014              other_adult_birthday_party             0.338601
# 6983          little_kids_2_7_birthday_party             0.772013
# 2008          little_kids_2_7_birthday_party             0.423795
# 5458           general_party_food_and_drinks             0.252814
# 12858                     bar_or_bat_mitzvah             0.112457
# 13475                              thank_you             0.711411
# 6192                               thank_you             0.305529
# 3201                          wedding_shower             0.403541
# 605                       bar_or_bat_mitzvah             0.115344
# 6939                               new_years             0.139157
# 1718                              valentines             0.158716
# 3999              other_adult_birthday_party             0.383676
# 9517                              graduation             0.154089
# 5573                                 holiday             0.445282
# 6642                          wedding_shower             0.506497
# 11468                   love_or_just_because             0.160282
# 9596              other_adult_birthday_party             0.300002
# 3058          little_kids_2_7_birthday_party             0.674781
# 51     baby_shower_or_new_baby_related_event             0.680758
# 2906          little_kids_2_7_birthday_party             0.776174
# 3596   baby_shower_or_new_baby_related_event             0.523130
# 1545              other_adult_birthday_party             0.293445

# %%
def _enforce_tertiary_hierarchy(row):
    
    primary, secondary, s_score, tertiary, t_score = row['final_primary'], row['final_secondary'], row['pred_secondary_score'], row['pred_tertiary_class'], row['pred_tertiary_score']
    expected_secondary = np.unique(hierarchy[hierarchy.t_class == tertiary].s_class)
            
    if secondary in expected_secondary:
        "tertiary hierarchy enforced"
        return secondary, tertiary

    else:
        
        if s_score > t_score:  # primary wins
            return secondary, 'unknown'
        else:
            if len(expected_secondary) == 2:
                return 'unknown', tertiary
            else:
                return expected_secondary[0], tertiary

# %%
def add_final_classes(X):
    """
    Enforce the hierarchy and add final classification
    """

    print("Adding final classifications to dataframe...")
    finals = X.apply(_enforce_tertiary_hierarchy, axis=1)
    finals = np.array([np.array([i[0], i[1]]) for i in finals])

    X.loc[:, 'final_secondary'] = finals[:, 0]
    X.loc[:, 'final_tertiary'] = finals[:, 1]

    return X

# %%
final_x = add_final_classes(x_test)
# Out:
# Adding final classifications to dataframe...
# /usr/local/lib/python3.6/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
accuracy_score(x_test['true_tertiary_class'], x_test['pred_tertiary_class'])
# Out:
# 0.65354330708661412

# %%
from datetime import datetime

# %%
import os
import logging
import psycopg2
import pandas as pd


LOGNAME = 'log/event_classifier_log'
logging.basicConfig(filename=LOGNAME,
                    filemode='a',
                    format='%(asctime)s -  %(name)s - %(levelname)s - %(message)s',
                    datefmt='%H:%M:%S',
                    level=logging.DEBUG)
LOGGER = logging.getLogger(__name__)


# connect to old cluster
HOSTNAME = '10.69.10.122'
USERNAME = 'iman'
PASSWORD = os.environ['DATABASEPASSWORD']
DATABASE = 'dev'


def upload_records(query, tup):
    """
    Accepts query string and connection
    Uploads result of query into table
    """

    connection = psycopg2.connect(host=HOSTNAME,
                                  user=USERNAME,
                                  password=PASSWORD,
                                  dbname=DATABASE,
                                  port=5439)
    # run query and store results in a dataframe
    LOGGER.info("Running query...")

    cur = connection.cursor()
    args_str = ','.join(cur.mogrify("(%s,%s,%s,%s)", x).decode() for x in tup)
    print(args_str)
    cur.execute("""
        INSERT INTO primary_classifications (event_id, primary_classification, primary_score, uploaded_time) 
                    VALUES """ + args_str) 

    connection.commit()
    
    cur.close()
    connection.close()

# %%
upload_records(query, tup)

# %%
tup = [(1234,'birthday',0.3, datetime.today()),
       (134,'birthday',0.663, datetime.today()),
       (1232324,'greeting',0.333, datetime.today()),
       (122734,'wedding',0.773, datetime.today())
        ]
        
tup
# Out:
# [(1234, 'birthday', 0.3, datetime.datetime(2017, 7, 7, 16, 17, 38, 493792)),
#  (134, 'birthday', 0.663, datetime.datetime(2017, 7, 7, 16, 17, 38, 493800)),
#  (1232324,
#   'greeting',
#   0.333,
#   datetime.datetime(2017, 7, 7, 16, 17, 38, 493803)),
#  (122734, 'wedding', 0.773, datetime.datetime(2017, 7, 7, 16, 17, 38, 493805))]
